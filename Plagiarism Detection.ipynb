# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Project-2: Locality Sensitive Hashing

# %%
import random
import os
import numpy as np

from random import randrange
from shutil import copyfile

import binascii

# %% [markdown]
# ## Execute the follwing two cells to generate your data sample

# %%
n_1=0
n_2=0
n_3=0

# %%
MY_ID = '692'
# MY_ID should be string
# Example MY_ID='819'

task_dict = {0:'taska',1:'taskb',2:'taskc',3:'taskd',4:'taske'}
id_dict = {0:n_1,1:n_2,2:n_3}

try:
    n_1 = int(MY_ID[-1]) % 5
    n_2 = int(MY_ID[-2]) % 5
    n_3 = int(MY_ID[-3]) % 5
    
    while n_1 == n_2 or n_1 == n_3:
        n_1 = (n_1 + 1) % 5
    
    while n_1 == n_2 or n_2 == n_3:
        n_2 = (n_2 + 1) % 5
        
except Exception as e:
    print('Please enter a valid ID...')

# %%
data_path = '/content/drive/My Drive/CS-5683/Project-2/corpus-20090418' 
# Edit this path if the data directory is not in the current directory

try:
    os.makedirs('Data_Sample')
    os.makedirs('Original_Sample')
except Exception as e:
    pass

for i in range(3):
    task = task_dict[id_dict[i]]
    
    for file in os.listdir(data_path):
        if task in file:
            if 'orig' in file:
                copyfile(data_path + '/' + file, 'Original_Sample/' + file)
            else:
                copyfile(data_path + '/' + file, 'Data_Sample/' + file)

# %% [markdown]
# ###Finding the number of docs created in Data_Sample and Original_Sample folders

# %%
p=0
q=0
for filename in os.listdir("/content/Data_Sample"):
    answerdoc=os.path.join("/content/Data_Sample",filename)
    p+=1
for filename in os.listdir("/content/Original_Sample"):
    answerdoc=os.path.join("/content/Original_Sample",filename)
    q+=1
print("Number of documents created in Data_Sample folder : ", str(p))
print("Number of documents created in Original_Sample folder : ", str(q))
# Out:
# Number of documents created in Data_Sample folder :  19
# Number of documents created in Original_Sample folder :  1

# %% [markdown]
# Your dataset for this project will be in <b>Data_Sample</b>
#
#
# Your query choices will be in <b>Original_Sample</b> directory
#
#
# You have to use any one original Wikipedia article from <b>Original_Sample</b> for <b>Fact Check</b> steps

# %% [markdown]
# ### STEP - 1: Shingling (20 points)

# %%
# Type your code here... 
# Create necessary number of cells below this cell
# k = 3

# NOTE: No complex text processing is required
# convert just upper case characters to lower case

# %%
samplefolder_3shingles=set()
samplefolder_4shingles=set()
samplefolder_5shingles=set()

# %%
def task1(folder_path):
  for filename in os.listdir(folder_path):
    answerdoc=os.path.join(folder_path,filename)
    f = open(answerdoc, "r",encoding='utf-8',errors='ignore')
    answer=f.read()
    tokens=answer.split()
  # Creating unique 3-shingles
    k=3
    for i in range(0,len(tokens)-k+1):
      samplefolder_3shingles.add(str(tokens[i]+" "+tokens[i+1]+" "+tokens[i+2]).lower())
  # Creating unique 4-shingles
    k=4
    for i in range(0,len(tokens)-k+1):
      samplefolder_4shingles.add(str(tokens[i]+" "+tokens[i+1]+" "+tokens[i+2]+" "+tokens[i+3]).lower())
  # Creating unique 5-shingles
    k=5
    for i in range(0,len(tokens)-k+1):
      samplefolder_5shingles.add(str(tokens[i]+" "+tokens[i+1]+" "+tokens[i+2]+" "+tokens[i+3]+" "+tokens[i+4]).lower())

# %%
task1('/content/Data_Sample')
task1('/content/Original_Sample')

# %%
print('Number of unique 3-shingles:' ,len(samplefolder_3shingles))
print('Number of unique 4-shingles:' ,len(samplefolder_4shingles))
print('Number of unique 5-shingles:' ,len(samplefolder_5shingles))
# Out:
# Number of unique 3-shingles: 3133
# Number of unique 4-shingles: 3347
# Number of unique 5-shingles: 3439

# %% [markdown]
# Report results (number of unique k-shingles) for k={3,4,5} below:
# 1. k=3: 3133
# 2. k=4: 3347
# 3. k=5: 3439

# %%
# Type your code to get the 5-shingle index here

# %%
# Creating 5-shingle index. In the data sample folder, for each doc, 5-shingles are created and stored in eachdoc_5shingles list. All these lists are added into
# fiveShingles_index dictionary with key as the doc name and value as its corresponding 5-shingles ascii values.
# So, fiveShingles_index length is nothing but number of documents in the sample folder.
# The value for each key in fiveShingles_index dictonary is 5shingles and length of that value is the number of unique shingles in that particular document.
def generate_shingles(filepath,k):
  fiveShingles_index={}
  for filename in os.listdir(filepath):
    answerdoc=os.path.join(filepath,filename)
    f = open(answerdoc, "r",encoding='utf-8',errors='ignore')
    answer=f.read()
    tokens=answer.split()
    eachdoc_5shingles=[]
    for i in range(0,len(tokens)-k+1):
      c=str(tokens[i]+" "+tokens[i+1]+" "+tokens[i+2]+" "+tokens[i+3]+" "+tokens[i+4]).lower()
      c=binascii.crc32(bytes(c,'utf-8'))
      if c not in eachdoc_5shingles:
        eachdoc_5shingles.append(c)
    fiveShingles_index[filename]=eachdoc_5shingles
  return fiveShingles_index

# %%
data_Sample_5shingleindex=generate_shingles('/content/Data_Sample',5)
Original_Sample_5shingleindex=generate_shingles('/content/Original_Sample',5)

# %%
# Printing 5 shingles ascii values for each doc in Data_Sample folder
for k, v in data_Sample_5shingleindex.items():
  print(k,v)
# Out:
# g3pA_taska.txt [1035909868, 1582887699, 4221836882, 3842591910, 404571842, 2006068679, 3380836256, 1612370110, 529410077, 2882352474, 3713884535, 3493799612, 959392395, 3578059022, 3759901248, 2064321880, 2439120550, 1295790681, 697192052, 4185068296, 3380817623, 2579204901, 2047462241, 2239221698, 3627392688, 2094125749, 990072640, 2123542211, 4250559168, 828804704, 2119770922, 1563804179, 2294401466, 495009510, 1825837325, 3787646925, 2459358623, 3079609220, 3928501365, 484678738, 3160705609, 4023615533, 192721792, 883554560, 2000792513, 1417713806, 905037320, 785961508, 994398730, 931254935, 3890730853, 2170796269, 3921563197, 3403101329, 1819071440, 1622312490, 2702065809, 2609012423, 770949410, 3217782129, 809748490, 4166173263, 400055276, 3070206049, 2250644597, 4232927265, 4128950149, 21758189, 1257216596, 985588743, 1974094271, 1524468365, 151245338, 3939494564, 1278089362, 3301707687, 3691738366, 1472669587, 3654289534, 1078196511, 2675165436, 313891569, 3673012795, 3829579334, 446596493, 1082368005, 3404400715, 2199288371, 542277273, 2715412236, 858890906, 2460193058, 3682936563, 947135121, 3885493207, 90779088, 2819492280, 961384441, 497009594, 2872059891, 488382104, 1397338969, 4005905234, 3384659044, 3466781838, 1408267791, 722755936, 4255134848, 2765673517, 982999935, 2411370863, 1150543190, 3071089715, 4096619330, 4262466592, 3437154102, 675138589, 161029957, 1451368326, 2967427413, 2635475774, 1831346333, 807023162, 1917124044, 1009730759, 3608583876, 3616557477, 123360135, 1215531678, 3972038630, 702116770, 1014570959, 4007056171, 1575432960, 3880889702, 2552164556, 47651523, 3789457234, 1376031570, 2606143083, 1668903419, 2650561937, 2625686925, 3882056525, 4167629653, 1160345890, 1481819974, 3617372290, 4000092039, 1800147336, 2363389242, 3171768192, 1217068742, 86520628, 3699790647, 1684901791, 2356644975, 1905247321, 1746950999, 701721156, 3483544083, 2391862195, 3920336833, 2356365116, 3570997058, 3022412466, 4108186566, 3773655813, 3418677948, 2242449986, 65954143, 3962760506, 256005323, 2898733153, 3276640861, 1074930803, 1034460502, 3776709631, 2651340770, 496373818, 3674495417, 1691222493, 1921896196, 454495432, 951851972, 1214716303, 3806038401, 3125126062, 3761704454, 1158302249, 3853305703, 2675804626, 1916276591, 2625636780, 3055984807]
# g0pB_taska.txt [3394399666, 3728198724, 172002015, 2546353171, 102778877, 1912469263, 3017228468, 133594176, 2146789698, 2416286241, 1798923039, 1686211934, 252401713, 2564465157, 3342043961, 2829436516, 2222500585, 734230723, 1594250784, 339476401, 1868678283, 3400494253, 3707845741, 2441108578, 1558661881, 1549947363, 3645347463, 3653031488, 3782814084, 3807840545, 1308964283, 3995490616, 2006789965, 1394382920, 2654711031, 2729585802, 963888337, 1059565104, 597396424, 2457331149, 2214313427, 4258561354, 1071616382, 544746800, 756517501, 1826657463, 2819883303, 2288699884, 2299826314, 2437512946, 103908099, 147718541, 1539235893, 3840024518, 3070190640, 114812307, 1824621184, 19625011, 3339635677, 314206331, 3120023741, 2785656988, 1591972196, 3222689654, 3195385648, 3716225286, 1923573458, 2647140327, 841563614, 414292450, 3628845191, 2162481701, 130127207, 735902079, 3666179296, 3329029968, 3468919504, 2045638340, 3234687289, 498974290, 1134630848, 3635771584, 911353023, 860277048, 4056989991, 1252879224, 1124825329, 2862210146, 2520317138, 4244630281, 4161188708, 3670874947, 57081065, 563420907, 2689514923, 1345927404, 3128097584, 255657191, 1301474884, 2871063503, 2522631400, 114818416, 2311830216, 2183989917, 3032009558, 3651196654, 1242266272, 4205470458, 1929374944, 3440863426, 3600516489, 3658400216, 4085225417, 3997246160, 2699723114, 2726760915, 3035999771, 295489063, 2214823106, 3979554949, 3616205692, 2340392162, 3097335854, 3766541287, 2579055949, 2797666348, 1101449552, 3239719810, 3469180525, 169292080, 4114576775, 3051522250, 1664448552, 1982028192, 2498535962, 899995159, 1492933217, 3076992668, 1746428389, 2205464312, 2194865478, 3448214479, 442205999, 2551927076, 3045452317, 2654565097, 1247762917, 3899551487, 320435817, 655253135, 3230504214, 2036849995, 2296262687, 1460084968, 3602586775, 1379505701, 3568080713, 3518052069, 2221619332, 908209292, 2899278351, 2812752138, 7941265, 625275564, 813858750, 257976207, 1735829965, 3448579739, 2033881063, 1891779806, 2113494064, 2623714919, 3351018148, 3739751938, 896426590, 2544841416, 1377801956, 1779349131, 1312464701, 1906256413, 1711625703, 1082456125, 109414087, 1996597051, 138955045, 1032432912, 2706435647, 3062520136, 3932975155, 3348257130, 2813440617, 405699731, 323569392, 566710367, 1261528909, 822232175, 2211521169, 956325133, 1182996038, 2753180923, 1569903270, 1491587013, 3115258727, 949187530, 921023219, 1437658398, 1602918514, 1158840134, 3605080244, 3876616250, 372626162, 1886515054, 2648455862, 892816763, 4277971493, 979583674, 3370173293, 3251138890, 938169765, 2918924511, 4094649074, 2305883292, 3638451733, 18796881, 2729869348, 2350205392, 485487636, 4291627646, 749369826, 1907673673, 1155222291, 3113461320, 3336178095, 3021628089, 1117833419, 779885904, 3092242575, 1861015478, 331717630, 3088206212, 3701875107, 1591129026, 1238430565, 3336872607, 2937702876, 2041021779, 1392952134, 26106089, 1435047293, 2676383247, 4200970447, 4007067062, 603607259, 1360952432, 1746110768, 1756106061, 1435080584, 3156920435, 1510576183, 1988476044, 3089646444, 1509428478, 2487348455, 1783505321, 977538220, 2713711060, 3067771880, 403321154, 4221497086, 3372500201, 48197813, 301085891, 3583321600, 3920579770, 3829568834, 1488197830]
# g4pB_taska.txt [904085400, 3384877711, 2315947324, 2638393872, 567829843, 1593445101, 2184112419, 410872067, 3732346644, 935040138, 1775037977, 1575675789, 459503956, 4149376146, 1778816188, 2594966975, 2481191756, 114775787, 2264908475, 3886333770, 1776460882, 3977176015, 2453925762, 2306376543, 4043549264, 699997691, 2707434109, 254729699, 1636755480, 2282948642, 754770274, 3962925948, 420838863, 1170926529, 2262663310, 3330152356, 1706452272, 810499212, 1963290006, 1906536811, 273799275, 1443952, 2177468837, 2164557707, 724154737, 3468735577, 698690254, 1448973360, 884049564, 656967346, 120859584, 127685960, 1407069990, 3869348243, 2622942039, 2765542438, 739000201, 4270882742, 3150018307, 1333213648, 3465474907, 3942823187, 3890081974, 2496384939, 1364601186, 1488009813, 596020876, 2179341396, 3425706325, 2544241711, 3150339753, 195133885, 1942285540, 3181377769, 866225315, 4277046619, 456229004, 1737931997, 197337094, 2989140117, 3343313154, 41598395, 3276029667, 2621432540, 2540073615, 2869933559, 3362485221, 2058298080, 1116242127, 3142237927, 948330681, 1759438307, 3181567660, 2104243149, 2343642148, 151246123, 4034153824, 3500553298, 2748038071, 3276577144, 1505923567, 2513830209, 753448144, 308413865, 3253931790, 69140225, 682307706, 2792852963, 3961451493, 4033539332, 4224004264, 1614878352, 608109259, 3227031691, 3189032940, 1023046103, 4691376, 2205152667, 4201621081, 3496213537, 2861869176, 2015435026, 328529299, 2888114576, 1277395921, 2964074217, 528428691, 1043855979, 4009228541, 3352823892, 808516503, 2523442807, 3982079857, 53024289, 332496891, 2795920485, 1313706337, 3006589875, 1066760849, 1072883165, 1932062666, 3873724868, 3885253318, 701511037, 1843636702, 572948932, 3117134114, 427210070, 2628274950, 1165029474, 2404976719, 2923029371, 3375468693, 2385940389, 3311536427, 1654457423, 3864963074, 2279023229, 2640942873, 2150022483, 3259439696, 2655763165, 3662098056, 2182407572, 3876920419, 2304393107, 1053884839, 3256955351, 3188895133, 3292569439, 3674008024, 4062947500, 3291605569, 1177525559, 1665629966, 574996381, 4175276058, 2995341803, 1420807420, 1489180285, 3732404008, 2673057339, 3542757626, 3032946721, 2630826053, 3065815545, 3201892289, 2839354193, 3883554060, 1142242330, 1490008069, 1450222757, 685965417, 3410064206, 1559035788, 1536577933, 3088756953]
# g0pD_taska.txt [1836271592, 2506085930, 290152195, 1426017662, 1883561718, 106079012, 386417840, 2428879660, 4241958983, 2359962303, 3576878252, 2670027072, 968175045, 4061552481, 1769612873, 1164183376, 4235003863, 421443857, 2866486908, 3798869516, 1566471313, 3007150453, 594637028, 3219052662, 3509114974, 2671884925, 1162414039, 3492701509, 3440845749, 1567226602, 156805830, 2756790454, 2279517860, 480330746, 4043496080, 1501133475, 1753369462, 2843102889, 3451990036, 1205250825, 3119544585, 1664744279, 4127472169, 885827554, 2504905430, 3711229382, 2423216601, 1558167495, 3822264706, 633810809, 4274401836, 1010734253, 1752429534, 2370446383, 1157082213, 4104727474, 3987608424, 293821768, 1461368634, 1412334183, 2335230381, 969700189, 4021842764, 1721126374, 4082665287, 3525096244, 74212827, 1446160187, 57960600, 2877398641, 1446256295, 219302160, 2332586777, 1762029701, 1350985590, 1341258284, 2378512492, 3492818801, 1807802045, 39868228, 3785696998, 1989055910, 467459719, 1774629770, 1535260864, 4133628099, 2963007426, 1916128529, 1724735003, 27695221, 427592712, 1750879183, 1066797028, 2191841344, 3874272778, 740865595, 2618378251, 3540464536, 3550944406, 755656858, 1494082539, 2275527111, 3222616604, 495606499, 2970951854, 1948985400, 2106971739, 2071375646, 1409355762, 4220296611, 3947499601, 994336980, 1413478770, 2796211866, 4190192049, 2907349466, 3277842434, 1525792105, 1005991921, 1681639631, 1445619414, 3530279092, 4208825427, 1666298309, 3559501881, 69345169, 1782702186, 905688390, 3907885010, 3966545610, 997652920, 2030330468, 3333357526, 2061484896, 3395033398, 1002000852, 1365549341, 2807312361, 2154197414, 4263055171, 2264117725, 715743026, 4006251814, 497712922, 1637319343, 2532357969, 2178513272, 2558777934, 3293747878, 2848434371, 3610844352, 2565881302, 2063142498, 3813729578, 133876743, 1472696636, 3154032026, 3876972120, 2187237585, 3629128589, 181686452, 2795950856, 4094074759, 1808563720, 3250564229, 959636533, 1080520389, 819880526, 655217200, 1021402564, 4047598823, 2802398819, 1552156918, 1960673684]
# g1pA_taska.txt [1541839628, 1221297018, 4184005415, 2552329943, 3514567870, 4006714568, 542217887, 2117080520, 4033885897, 2020081659, 1132836699, 3999422425, 3879390860, 3885739477, 3832173065, 3255303146, 3800493949, 3740344047, 552269466, 2547918452, 2934780651, 2416513582, 2464614122, 2601190437, 2372851920, 3171583766, 3040349130, 1191814705, 4133075699, 1890111010, 3747399654, 4269820198, 140670144, 2287500581, 267805657, 3395816678, 4265937495, 3833632912, 2963534579, 2735988787, 1743294858, 380391018, 3918552146, 259356152, 455112582, 3405287203, 3170584290, 2513309004, 2785927342, 3260513461, 141188584, 263900592, 664111573, 1414967896, 2781607878, 2290386598, 1424372109, 215409533, 2249805810, 21969565, 3236966169, 3827688224, 417162842, 15590604, 3985863104, 1876236705, 2012474957, 3606091125, 889873637, 3322489848, 3845174024, 840333526, 3293432967, 3086956777, 1457695197, 2152681769, 1300045837, 3652835514, 770715519, 1734884898, 3755594592, 681858152, 2178681865, 1317513615, 841381360, 124771772, 600810640, 4128984059, 4135613997, 2243376121, 3864092121, 2261868110, 1203764397, 977313306, 2961734163, 459817968, 176018017, 1970314531, 3035288941, 3575627898, 1797593821, 4215733362, 2117647123, 2769272176, 663083032, 1698145405, 1138086535, 718118934, 2493553935, 1475989792, 1532054438, 3857814291, 3222195074, 1194373342, 1672591946, 1125382902, 521673184, 871755257, 3509991363, 3791836623, 3065520989, 3882770328, 1571967262, 321047129, 4235874842, 1890899435, 4119730307, 3557518215, 3151542814, 2976856461, 2374272617, 1049830404, 3928540096, 1918107941, 3142651852, 3416154729, 3709877555, 1158881850, 3746555293, 431196432, 3074516550, 2888190514, 1035271614, 878104140, 1158955862, 1652871629, 888762231, 3607904294, 3108965630, 2666081956, 3337915986, 1542662881, 581979786, 634009295, 3111353436, 254523477, 2704895833, 562632885, 1734704046, 1421907550, 2369281148, 1593152273, 1354372451, 2358136901, 3645783846, 4276804504, 472755747, 2170766102, 1078294713, 397651062, 3829657300, 3305604, 230408515, 2939674516, 3082010319, 973444943, 804303769, 925814025, 1366541500, 3780770719, 2744056960, 2975685921, 4290359158, 120786733, 2647370875, 1327890916, 90199462, 650753461, 3593072920, 3706145395, 3363336901, 1592856346, 1490510341, 2823123126, 2520151605, 4254981062, 4102173398, 2397587731, 3245904340, 2576134985, 1354795045, 26682870]
# g1pD_taska.txt [1133140353, 3153054226, 1257347197, 2715612970, 4084527145, 934808362, 3897677747, 2269959718, 4057306915, 1160238715, 1359744008, 3660868905, 449750355, 1130548325, 4084003537, 2032778236, 3321897570, 4095122836, 1287337018, 3370504022, 3530779175, 3614955339, 3424679262, 3981228615, 1161695709, 2032580700, 3068825670, 611994183, 2198075028, 3929597232, 1301427978, 1658951576, 2345754004, 133937116, 2379922032, 1091209022, 791034793, 4157463703, 2311795445, 2342580415, 221986774, 3378126518, 1218368195, 3073721054, 3030621029, 2065366830, 71351283, 1286510780, 4187836544, 162363326, 4259330740, 1174971464, 3746635925, 354206106, 2118209011, 4001892637, 2304163949, 3247998236, 1166856889, 3891437781, 1696414599, 1683346476, 608424862, 1090133471, 3974694210, 2864103749, 1019907181, 1302624531, 1807268491, 3801554832, 1037634550, 1254871782, 1775870097, 3643437479, 3652638150, 3374432239, 3861668031, 2900186641, 3098740117, 3309870831, 2129397729, 3113909279, 3198234446, 3005434085, 39294148, 791558667, 172133111, 1916128529, 1724735003, 27695221, 427592712, 1750879183, 4009663228, 3112879116, 4095342043, 2776517971, 326787958, 2338887680, 1758421148, 1769170656, 2746208952, 3002574855, 3772987125, 3281178570, 1659437012, 4104341805, 3787726735, 3250894972, 3276130980, 69131377, 741574107, 1919784436, 3154646894, 142408113, 3902920466, 2568464479, 2997058023, 2709833805, 3678140379, 3885344637, 2223259424, 1729585205, 1326045884, 3881756911, 2883597527, 1846811020, 1664119892, 2019630702, 3248593066, 743312907, 2423623707, 3768444820, 3381083701, 932250351, 2625331745, 2786488864, 1934927855, 1951436324, 2054257092, 2906193794, 2517898824, 1613340386, 2426817996, 720513068, 1412334183, 2335230381, 969700189, 4021842764, 1721126374, 4082665287, 3525096244, 3193471326, 661377233, 2542700210, 2301498353, 2574048349, 3060189548, 2535290424, 2358373007, 3645011194, 4209130348, 3085086764, 1560623411, 1244990459, 1728761833, 3825688647, 1533702889, 1947112652, 2425543493, 3966365992, 4228452894, 2007362783, 3250589627, 3595541724, 1542935525, 3060985422, 1493973528, 648816085, 3551414299, 984849624, 3449458152, 4213694342, 1083196862, 2389637178, 2672968852, 278112507, 586650751, 4222621211, 339565384, 3424391288, 2027422573, 3971135444, 484326822, 670847680, 1509261625, 629739298, 4104056165, 431981207, 3638025056, 376261099, 1186716135, 2488482031, 3713656608, 1463180924, 4037731779, 186137210, 2628361305, 2301265589, 931341513, 244243945, 1624837575, 330874573, 434689023]
# g0pC_taska.txt [1836271592, 2506085930, 1389598181, 4253818187, 3297088911, 4130684126, 3161373380, 1586780672, 3145543285, 1518717930, 2577054766, 2732697338, 3432042090, 191552248, 3544495456, 3915475754, 795166556, 1701280192, 70929028, 1602603136, 713798449, 482027125, 3652812959, 2172580929, 226847358, 2472360922, 3766416058, 3210665063, 413109333, 4090740255, 2702956400, 2922554376, 1842890770, 862690366, 1579284860, 3934078324, 1615805071, 366340859, 3253571423, 382829588, 2929834323, 1003032085, 2711777205, 3287670817, 3537729625, 851987309, 4015927251, 1923103457, 1856639233, 2335502639, 770084028, 855436555, 1852643865, 2833731902, 3363634558, 917039857, 1186818255, 184263736, 3670558775, 3869812165, 3859502884, 2291830063, 1937306355, 1813204948, 1110981048, 1130072416, 3865738859, 963253725, 1094063879, 1138339244, 3329232282, 2404187330, 1900211777, 1276827379, 650874522, 675766180, 3955503593, 649896623, 962411264, 4142463730, 1789153759, 1485043326, 884354972, 2139059557, 2873547241, 2065917394, 1645549087, 4274907795, 2441222581, 1534368136, 1721852635, 128666220, 4159122066, 424143778, 2718579348, 4119201190, 2171608485, 1459066278, 3975889290, 770411030, 3304571997, 1520838696, 1590154412, 1392509791, 945311165, 1691073636, 3703604404, 2668972884, 2798026205, 712877888, 3900000901, 3329529255, 2020052103, 1827751730, 212805052, 2998441271, 1460211876, 2650191880, 2109984804, 2510605583, 376393598, 2532736592, 484646126, 3560660464, 4170932838, 2923284613, 3130254915, 3603906559, 3967638025, 3154032026, 3411008330, 2915285845, 2079182317, 253765237, 2187601734, 3310276845, 1924424328, 1649695336, 876790003, 2331691667, 3862332496, 1954563040, 1464765649, 3236639533, 3251077881, 1802836355, 394033621, 102889988, 930134693, 2210493838, 802030531, 1552156918, 1960673684, 1095517928, 3382103904, 3599470251, 1665994179, 995783430, 1465266684, 2197561676, 2654684621, 2105028207, 273402924, 3415279039, 70453889, 2902723157, 1275484225, 1111965853, 380664104, 1930584235, 3905941553, 762874400, 53320262, 1779346799, 1356176691, 1980558038, 823976584, 1623208460, 847973054, 3084453381, 1122704067, 370528826, 2272092955, 2707314687, 1257566085, 2956566298, 1621861433, 2207134374, 1446160187, 4026764636]
# g4pC_taska.txt [1035909868, 3522252604, 3650526023, 2415088819, 106079012, 386417840, 2428879660, 1636707444, 872100460, 2070353702, 894738349, 2086421377, 1647580203, 2650612638, 3596835944, 1397217018, 686424120, 968175045, 4061552481, 1769612873, 1164183376, 1172303953, 197289567, 332416369, 3564084430, 1814713470, 4107243968, 2893812946, 1899184820, 1784632175, 935106865, 2543359637, 1470576969, 687854264, 1214439492, 184395841, 4187836544, 162363326, 4259330740, 735396003, 3959158388, 1835753496, 2159643322, 778637223, 308237136, 1091345905, 4256990993, 1759767805, 3479633242, 3362358661, 1710466, 2079628569, 1841911956, 204648415, 2864103749, 1019907181, 1302624531, 1807268491, 3801554832, 250892653, 3444534852, 1651406132, 2843854633, 89368477, 520627703, 2372361686, 4204947023, 3984524694, 2149528414, 147704711, 1592602593, 3758347120, 1896395363, 3741257556, 367763611, 4148710765, 641731714, 3798869516, 1566471313, 3007150453, 821103029, 2593255283, 558682633, 3127021506, 348932217, 1289974384, 4249238232, 3545989964, 1099188612, 1399248073, 3647139428, 3703599356, 902908492, 2344093736, 480330746, 4043496080, 1501133475, 1351810778, 3647544276, 3743064535, 3453396159, 2844940844, 934695594, 810909792, 2347918734, 2423216601, 1558167495, 3822264706, 2811734458, 1252468044, 2541320878, 1436389364, 2096345873, 2369231483, 775395997, 1286144944, 1186773681, 3083670880, 39868228, 3785696998, 1989055910, 325294962, 2947052942, 3363530049, 1050051865, 9408795, 1916128529, 1724735003, 27695221, 427592712, 1750879183, 3163488223, 2767191386, 1578059722, 3429803910, 2176781747, 1750652007, 1567384800, 3443551103, 13500466, 827335375, 1130702791, 646784272, 2308933436, 1204061776, 524416111, 2071375646, 1409355762, 4220296611, 3947499601, 994336980, 1413478770, 2796211866, 4190192049, 2907349466, 3277842434, 1525792105, 419785404, 2592478807, 2921047591, 225826009, 492984438, 4208825427, 1666298309, 3559501881, 69345169, 1782702186, 2495438552, 2751280597, 1257384031, 1159595757, 3333357526, 2061484896, 3395033398, 1002000852, 1365549341, 2807312361, 2154197414, 4263055171, 2264117725, 715743026, 4006251814, 497712922, 1637319343, 2532357969, 2178513272, 2558777934, 3293747878, 2848434371, 3610844352, 2565881302, 2063142498, 3813729578, 133876743, 1472696636, 3154032026, 3876972120, 2187237585, 3629128589, 181686452, 2795950856, 4094074759, 1808563720, 3250564229, 959636533, 1080520389, 1905144219, 765551172, 3811757916, 19420116, 1675097331, 1552156918, 1960673684, 1196882081, 3879680720, 1429979577, 1758399809, 3816100538, 805147146, 1437875675, 977379383, 148041192, 2482909174, 1079080651, 3510319730, 1056332005, 4153437414, 3440974417, 3930340311, 686454280, 2607765866, 1164930787, 2738204602, 2389708484, 1980558038, 1951436324, 1468243728, 2278137137, 1501854149, 4104727474, 3987608424, 1258841796, 2856392272, 1610700597, 1869204096, 689900833, 969700189, 4021842764, 1721126374, 4082665287, 3525096244, 74212827, 1446160187, 57960600, 2877398641, 1446256295, 219302160, 2332586777, 1762029701, 3085086764, 1624720636, 1253277695, 1102811774, 822206685, 3247336154, 1570601185, 1340349598, 2163164539, 1784769955, 1166957135, 692577982, 3759297686, 1168183031, 234637288, 839254698, 246217866, 419610594, 482823259, 4188250032]
# g0pE_taska.txt [1035909868, 3522252604, 3650526023, 2415088819, 106079012, 386417840, 2428879660, 1636707444, 872100460, 2070353702, 894738349, 2086421377, 1647580203, 2650612638, 3596835944, 1397217018, 686424120, 968175045, 4061552481, 1769612873, 1164183376, 1172303953, 197289567, 332416369, 3564084430, 1814713470, 4107243968, 2893812946, 3265898133, 506707586, 151640360, 3980593147, 2424194053, 3798869516, 1566471313, 3007150453, 821103029, 2593255283, 558682633, 3127021506, 3263055433, 1252387849, 322855997, 110368829, 3650761910, 1965279511, 1610932594, 3703599356, 902908492, 2344093736, 480330746, 4043496080, 1501133475, 1351810778, 3647544276, 3743064535, 3453396159, 2844940844, 934695594, 810909792, 2347918734, 2423216601, 1558167495, 3822264706, 2811734458, 1252468044, 2541320878, 1436389364, 2096345873, 2369231483, 775395997, 932054888, 2453987871, 2081512033, 687854264, 1214439492, 184395841, 4187836544, 162363326, 4259330740, 735396003, 3959158388, 1835753496, 2159643322, 778637223, 308237136, 1091345905, 4256990993, 1759767805, 3479633242, 3362358661, 1710466, 2079628569, 1841911956, 204648415, 2864103749, 1019907181, 1302624531, 3900462815, 3983539585, 16337946, 2433495, 457892948, 1537381683, 1004150057, 2786664109, 3439293222, 1550587169, 3172289034, 2899196164, 3787597926, 1038636143, 3742002473, 3028026826, 995772961, 1280052140, 1936089769, 1378777799, 3918834569, 859004922, 1027085553, 1651406132, 2843854633, 89368477, 520627703, 2372361686, 4204947023, 3984524694, 2149528414, 147704711, 1592602593, 3758347120, 1896395363, 2075822635, 3294861906, 4153939459, 2876027697, 39868228, 3785696998, 1989055910, 325294962, 2947052942, 3363530049, 1050051865, 9408795, 1916128529, 1724735003, 27695221, 427592712, 1750879183, 3163488223, 2767191386, 1578059722, 3429803910, 2176781747, 1750652007, 1567384800, 3443551103, 13500466, 827335375, 1130702791, 646784272, 2308933436, 1204061776, 524416111, 2071375646, 1409355762, 4220296611, 3947499601, 994336980, 1413478770, 2796211866, 4190192049, 2907349466, 3277842434, 1525792105, 419785404, 2592478807, 2921047591, 225826009, 492984438, 4208825427, 1666298309, 3559501881, 69345169, 1782702186, 2495438552, 2751280597, 1257384031, 1159595757, 3333357526, 2061484896, 3395033398, 1002000852, 1365549341, 2807312361, 2154197414, 4263055171, 2264117725, 715743026, 4006251814, 497712922, 1637319343, 2532357969, 2178513272, 2558777934, 3293747878, 2848434371, 3610844352, 2565881302, 2063142498, 3813729578, 133876743, 1472696636, 3154032026, 3876972120, 2187237585, 3629128589, 181686452, 2795950856, 4094074759, 1808563720, 3250564229, 959636533, 1080520389, 1905144219, 765551172, 3811757916, 19420116, 1675097331, 1552156918, 1960673684, 1196882081, 3879680720, 1429979577, 1758399809, 3816100538, 805147146, 1437875675, 977379383, 148041192, 2482909174, 1079080651, 3510319730, 1056332005, 4153437414, 3440974417, 3930340311, 686454280, 2607765866, 1164930787, 2738204602, 2389708484, 1980558038, 1951436324, 1468243728, 2278137137, 1501854149, 4104727474, 3987608424, 1258841796, 2856392272, 1610700597, 1869204096, 689900833, 969700189, 4021842764, 1721126374, 4082665287, 3525096244, 74212827, 1446160187, 57960600, 2877398641, 1446256295, 219302160, 2332586777, 1762029701, 3085086764]
# g2pC_taska.txt [2415088819, 106079012, 386417840, 2428879660, 1636707444, 872100460, 2070353702, 894738349, 2086421377, 1647580203, 2650612638, 3596835944, 1397217018, 686424120, 968175045, 4061552481, 1769612873, 1164183376, 4235003863, 421443857, 2866486908, 3798869516, 1566471313, 3007150453, 821103029, 2593255283, 558682633, 3127021506, 348932217, 1289974384, 4249238232, 3545989964, 1099188612, 1399248073, 3647139428, 3703599356, 902908492, 2344093736, 480330746, 4043496080, 1501133475, 1351810778, 3647544276, 3743064535, 3453396159, 2844940844, 934695594, 810909792, 2347918734, 2423216601, 1558167495, 3822264706, 2811734458, 1252468044, 2541320878, 1436389364, 2096345873, 2369231483, 1773568464, 3896875429, 2202896679, 632925294, 1472696636, 3154032026, 3876972120, 2187237585, 3629128589, 181686452, 2795950856, 4094074759, 1808563720, 3250564229, 959636533, 1080520389, 1905144219, 765551172, 3811757916, 19420116, 1675097331, 1552156918, 1960673684, 1196882081, 3879680720, 1429979577, 1758399809, 3816100538, 805147146, 1437875675, 977379383, 148041192, 2482909174, 1079080651, 3510319730, 1056332005, 4153437414, 3440974417, 3930340311, 686454280, 2607765866, 1164930787, 2738204602, 2389708484, 1980558038, 1951436324, 1468243728, 2278137137, 1501854149, 4104727474, 3987608424, 1258841796, 2856392272, 1610700597, 1869204096, 689900833, 969700189, 4021842764, 1721126374, 4082665287, 3525096244, 74212827, 1446160187, 57960600, 2877398641, 1446256295, 219302160, 2332586777, 1762029701, 3085086764, 3211873343, 1706102025, 3766726733, 3501675571, 1556932538, 4167321759, 220164944, 2713579772, 584638749, 1662230343, 1651905600, 4286216899, 3814383230, 3916123130, 1095560452, 2988542293, 3795386764, 1545061778, 103824239, 3705461713, 3256198127, 3570369842, 3679289671, 3043244667, 535277429, 3502781461, 2939966739, 147888881, 3268098165, 1957094028, 2006286868, 1294002147, 644928441, 684917201, 3066168300, 2386384658, 513405296, 1965009426, 1647723105, 831265301, 1788533222, 4144587553, 1548997003, 2689520690, 1324242792, 1844004782, 291230294, 2554814839, 2647625172, 1493105641, 2529043722, 2960894760, 299830410, 2728583242, 1063009565, 4187261898, 3366118361, 2565990673, 1628142871, 3870934199, 125172056, 3276422406, 2532194035, 706929450, 2451968982, 62210519, 1529452799, 12169485, 2371070123, 267001487, 3999950233]
# g3pC_taska.txt [1035909868, 3522252604, 3650526023, 2415088819, 106079012, 386417840, 2428879660, 1636707444, 872100460, 2070353702, 894738349, 2086421377, 1647580203, 2650612638, 3596835944, 1397217018, 686424120, 968175045, 4061552481, 1769612873, 493369911, 3590385545, 1487624097, 3496627879, 39868228, 3785696998, 1989055910, 325294962, 2947052942, 3363530049, 1050051865, 9408795, 1916128529, 1724735003, 27695221, 427592712, 1750879183, 3163488223, 2767191386, 1578059722, 3429803910, 2176781747, 1750652007, 1567384800, 3443551103, 13500466, 827335375, 1130702791, 646784272, 2308933436, 1204061776, 524416111, 2071375646, 1409355762, 4220296611, 3947499601, 994336980, 1413478770, 2796211866, 4190192049, 2907349466, 3277842434, 1525792105, 419785404, 2592478807, 2921047591, 225826009, 492984438, 4208825427, 1666298309, 3559501881, 69345169, 1782702186, 2495438552, 2751280597, 1257384031, 1159595757, 3333357526, 2061484896, 3395033398, 1002000852, 1365549341, 2807312361, 2334915498, 3591702493, 1596051539, 1262527776, 935793353, 497712922, 1637319343, 2532357969, 2178513272, 2558777934, 3293747878, 2848434371, 3610844352, 627157504, 2793002594, 1110619194, 2750123818, 1501854149, 4104727474, 3987608424, 1258841796, 2856392272, 1610700597, 1869204096, 689900833, 969700189, 4021842764, 1721126374, 4082665287, 3525096244, 74212827, 1446160187, 57960600, 2877398641, 1446256295, 219302160, 2332586777, 1762029701, 3085086764]
# g2pB_taska.txt [1906590412, 402135700, 1118167545, 1386515475, 817696863, 2371662309, 2751447771, 2044614189, 4199283343, 3975244928, 2201405017, 2571722733, 3463414094, 1486260936, 1085271332, 1369622711, 3885577232, 1239557898, 707399424, 287466880, 1106853053, 3979326001, 3856529649, 84797319, 3134134852, 1618492991, 1034788083, 2483839518, 1288904492, 3812987456, 3048518843, 598413097, 1887617565, 1427923556, 263660838, 832019496, 1709948463, 43448425, 1886374707, 2343809427, 1983979510, 150830063, 1145758493, 888197080, 2374191163, 2853768875, 1997362730, 3256186335, 3408989388, 3240358336, 2212072490, 2129713340, 1449283485, 1093409908, 2691154606, 4207704017, 1637928092, 3956226920, 108829569, 2537960307, 241863649, 1611383475, 760765945, 173388189, 1220669940, 1964256401, 3393007498, 1605870135, 806243328, 337073333, 846666166, 4064762002, 2549399287, 2451702397, 2742846435, 3048246199, 2402879921, 554646658, 1624492648, 1223033239, 99366957, 964680085, 243458675, 2816010857, 940294245, 1311900960, 1936268412, 3299485898, 1411583829, 2279579799, 538893234, 2783223963, 1692667300, 2827776734, 1225740830, 1167130483, 565718954, 4148034599, 2785778643, 2668149667, 1169325241, 3904262532, 2727097294, 1438709032, 4080461829, 3896834195, 3553550581, 1510238761, 229937570, 3013950538, 898686647, 669427958, 3745362072, 3182773505, 698064018, 3089482505, 2814676306, 4237057203, 389065166, 2827237157, 2464455504, 2191615149, 3992907954, 807443991, 4200125953, 3237477677, 891738940, 4228526429, 1108850154, 1131669921, 2194022869, 304280968, 673840764, 1248071939, 893091148, 920785898, 749754231, 755811512, 1064937333, 737399902, 4166590022, 1771801931, 3481184643, 281695052, 603697174, 1648446818, 3859310900, 2898109233, 715333816, 999991505, 4283505615, 3904815413, 2909199630, 2758172296, 3567946143, 2184944580, 3521262582, 2872156219, 1277914912, 4088827515, 2222882783, 633232845, 3090524506, 2831162835, 3103040311, 2670411740, 2665315497, 3333274840, 3490234384, 3082446210, 2686782251, 1199685098, 4119819366, 3554372816, 2182058286, 1055973248, 2505194461, 1227058532, 1572507646, 177408803, 135882530, 2352978197, 1863501815, 3525200378, 3817318763, 3026434393, 4082877767, 321409013, 213093726, 3545379217, 3282144169, 1522245884, 3130103623, 2216425371, 3031491405, 2392843145, 3228145672, 1248423507, 1480334479, 1777899965, 3308383164, 436502947, 1786530110, 545204353, 4125701195, 4197692877, 2694353749, 386422337, 1765353439, 16000338, 998351367, 210635268, 1934698411, 3547102572, 3859302048, 1674730296, 634776539, 2391306391, 927207970, 231157722, 47801794, 127627925, 3212609093, 1495510139, 2242945836, 3930906099, 3791025736, 1864684097, 3330463816, 2847248617, 1112486409, 1945913423, 1780841284, 805619434, 1461320614, 2214265835, 3889081904, 315618277, 3854317893, 130923342, 1426840194, 4271072640, 2069379894, 1505070900, 1443727858, 3044544804, 2885225622]
# g0pA_taska.txt [3394399666, 2260132848, 1196387329, 10238725, 826218319, 3836587125, 2012226513, 3183624262, 3928800356, 2683959759, 946504459, 3053878790, 2776642358, 1205138047, 2743142081, 3532657516, 2882737461, 2510296218, 3511027275, 1667765321, 1026523649, 2596127923, 207681559, 3570419975, 3977904608, 4062041280, 3978159770, 846354000, 694136685, 3415958403, 3868532268, 2414919550, 2611358250, 562573414, 282589634, 3491907148, 1216872130, 107629405, 3245684268, 2032394295, 2629859642, 3310473419, 1514293136, 2507914234, 3720523998, 351037485, 2017797499, 547723975, 3227980399, 1681582296, 659729418, 2157769443, 3896399710, 1276717722, 2153630124, 1892535211, 1897307755, 2489213468, 3081801211, 661233382, 3423865341, 744945673, 1595569196, 842866467, 4133844720, 2618984245, 3795492232, 4194397076, 1097483718, 2554821635, 3562908655, 3209836412, 2665939804, 1783762045, 3474514988, 1387558870, 3179921212, 2301775435, 3553365683, 1917930590, 2382324204, 3359973456, 209912768, 1301016519, 3354625890, 954676892, 706290091, 462339725, 1999834937, 4243562769, 2537251792, 311598313, 2997501664, 1883143074, 1441163041, 2316555428, 6584067, 2993850506, 2557416242, 597177906, 323004895, 2305254400, 1096759505, 952007684, 3972194402, 1910735905, 2599154935, 33980866, 4075867189, 1510048416, 1322286354, 2650564941, 975018884, 1131711083, 692879692, 1406477157, 2771800933, 2852076041, 3710566137, 588109423, 1604629370, 988814128, 521021947, 2583617487, 441915769, 656366425, 3438688796, 3009991083, 1149755346, 2757808691, 3296207466, 2942804321, 1431042237, 3692128571, 885477866, 1865386373, 2930721627, 2597070551, 927440355, 637985408, 3187778697, 1481947541, 1169492829, 3286287002, 2615220638, 1446931896, 3461695017, 2252388425, 3443028439, 4065952784, 2077264078, 3030822766, 4054010852, 141206057, 2812534257, 1256897543, 1976624195, 1734594007, 2553419521, 55012835, 1389116421, 1076056830, 4009428945, 2345539154, 2714379919, 3432696781, 991500126, 2722610167, 2882810256, 1210414423, 2790049649, 3960231017, 4107547749, 278767658, 2715754608, 2645142204, 74309092, 3473553961, 2022481109, 2827389062, 2785848319, 930119771, 3196803409, 777429813, 3190495221, 642459969, 2145691643, 1096807887, 3377240152, 975614645, 31217689, 3837945104, 2628901075, 1725889952, 4070161031, 247579545, 709470616, 3571315636, 793653845, 2989856568, 2548401463, 2736775328, 1013605364, 2390124596, 2309958140, 2004236327, 1903929366, 4042855425, 2351771989, 2757172705]
# g4pD_taska.txt [1180119072, 2816048390, 1217528327, 1626612381, 2366123849, 1098851437, 735956260, 263356200, 1888818331, 2844445061, 3480396573, 2224587335, 2438168709, 2649502979, 2262798367, 3915645240, 2701983895, 276495950, 3032801940, 1676145099, 3844043757, 1361845234, 4565586, 2990066234, 3648995094, 3542014192, 2515456473, 3695174701, 314601664, 1153620019, 3138513765, 2207992101, 80425379, 3080754436, 2946829401, 2400388538, 191145232, 1580022608, 3805552992, 3909588932, 4057128755, 1765030284, 2775443719, 3043175291, 2604979170, 2118570978, 3346773893, 384320215, 3956682928, 1087481969, 3627078768, 776020907, 3642202123, 1633850536, 2959130008, 14429048, 1880743035, 4228251617, 1345062692, 1623503822, 2307463843, 864340247, 2593747435, 3871073911, 3531319494, 232407825, 24686498, 626089209, 3128185706, 1705745491, 1985270060, 4170454737, 2175808285, 3049145084, 1305636215, 1436389364, 2096345873, 821952023, 822667646, 1876249936, 1751479159, 136160358, 1849344231, 755165743, 402083964, 3911326393, 1642045110, 3256193990, 2849194469, 4205599325, 659004786, 2887560796, 3843626594, 3004667511, 735396003, 2668851744, 150952136, 3725327758, 1465465077, 3273270124, 980545361, 3540169532, 1032370221, 11283649, 2568087402, 2218913121, 2561030903, 3087649851, 204648415, 793659163, 3273101432, 3918520424, 2581873524, 3759001630, 3801554832, 250892653, 532127326, 2244033600, 429509295, 3818906264, 1257686295, 1760682674, 2784844762, 1298315443, 1644921834, 2007197315, 2854228028, 331760925, 1156807369, 4170067988, 635172837, 3553393685, 3172289034, 2899196164, 189680822, 4045268723, 296224300, 2698421988, 2140570192, 356520997, 2808555973, 1924512115, 1382343029, 2810994572, 3447300036, 3605241566, 3096081829, 2854269704, 2386059942, 1481836036, 3488188270, 2046744096, 3406988127, 3960491729, 2372361686, 4204947023, 3984524694, 2149528414, 2946292295, 884311883, 2097981916, 1353795048, 3318398638, 2789919382, 599676624, 288291966, 1577964152, 2246322462, 3906165899, 3222300001, 3406885095, 4030622124, 2071595546, 3014756837, 3378146324, 4285822602, 3022951936, 2205014685, 2809036535, 2586059032, 4221548856, 1655378602, 3987532455, 645186493, 1981928246, 371230591, 100716777, 807815055, 1573216003, 819880526, 2400504635, 4269504976, 3495588512, 2673253315, 1139980302, 1208211554, 1105186785, 1960673684]
# g2pE_taska.txt [611144374, 3065374645, 2871415531, 3121959794, 3341218429, 950921165, 4034178411, 2712617802, 954153861, 3416465034, 584030956, 1711578965, 3507979744, 3722654165, 2893812946, 749193145, 3266542884, 3074150554, 2231685399, 2128083097, 1707881862, 1370272777, 46492335, 2974872206, 32710206, 386417840, 2428879660, 875340443, 325409278, 3737776254, 2318153736, 1214736502, 125923671, 3943004718, 2929909271, 3865281619, 1495377175, 963063228, 4155599037, 688975722, 4104160111, 3430399903, 968175045, 4061552481, 1769612873, 2779156429, 3847906586, 2830555389, 4020439681, 911704506, 2950209731, 944329112, 3822264706, 2811734458, 1252468044, 2541320878, 1436389364, 2096345873, 821952023, 2675762373, 2127862248, 1233688925, 805616809, 319130859, 3652926443, 214846886, 178149433, 2153764336, 1793612452, 348932217, 1289974384, 4249238232, 3545989964, 1099188612, 1399248073, 3647139428, 3218736420, 2706967264, 1602049633, 2077788658, 3161138047, 1351810778, 3647544276, 3743064535, 3453396159, 2836640984, 2366342847, 592319019, 884529024, 4208872905, 3127052764, 2055756027, 1613495140, 2317939658, 3212812870, 3111906022, 3072900094, 2738369765, 1403529123, 1360687174, 2935586678, 1274423640, 687854264, 1214439492, 184395841, 3818257458, 3169381112, 218195149, 3767656864, 463982312, 3322733236, 1186940026, 3979911819, 3518554555, 3738143423, 1764091477, 2178364427, 402839190, 341345562, 2618863369, 1913884850, 1505987871, 1355925554, 3897724786, 1537381683, 1004150057, 2786664109, 3439293222, 1550587169, 3172289034, 2899196164, 3787597926, 1038636143, 3742002473, 3028026826, 995772961, 1280052140, 3038665352, 586144861, 3629777431, 4562775, 1334079466, 940704085, 1525792766, 2072727797, 814010138, 787110186, 367205428, 2362256567, 339875814, 3690181178, 3984524694, 2149528414, 147704711, 2386452408, 1805602134, 135238223, 4253830334, 1382763222, 3897702333, 1150129837, 1459210386, 2767871390, 2282019016, 4159467871, 4103484406, 3201967203, 3680272239, 1567384800, 3443551103, 13500466, 827335375, 1130702791, 646784272, 2308933436, 1204061776, 2971151237, 1122720035, 696011266, 4225058574, 1803472808, 599001218, 571353949, 2030303204, 2425554397, 3699170903, 2036766184, 3062743758, 3868411575, 1540220426, 1916128529, 1663688878, 2865734319, 2292530112, 1594996305, 3021559766, 1999810662, 534642341, 17393669, 1701176339, 4229360968, 3747058047, 3929655143, 3371406270, 3551027509, 1238424666, 3277842434, 1525792105, 419785404, 2592478807, 2921047591, 225826009, 1503737151, 3105518025, 967090397, 1544923487, 1437926284, 1043353688, 2061484896, 3395033398, 1002000852, 1365549341, 2807312361, 2154197414, 4263055171, 2264117725, 715743026, 4006251814, 497712922, 1637319343, 2532357969, 2178513272, 2558777934, 3293747878, 2848434371, 3610844352, 1651415944, 4160107427, 3356177477, 2432507027, 1152450532, 2408747924, 3188723382, 419356805, 3680653362, 563656841, 629858389, 423791241, 1161289095, 2924061031, 819880526, 2984401841, 1800768626, 4265913161, 2143757646, 2889727900, 1844733400, 1552156918, 1960673684, 4154551057, 2770610690, 2393525997, 3082194656, 1916406378, 3545798812, 4052349012, 2037674359, 2350499263, 4144320318, 3070744607, 2293002857, 2521190326, 184165245, 1233570971, 1179754920, 160006565, 2686890546, 2129069396, 1321900466, 1991048090, 2677824634, 3273816319, 432203492, 4095108159, 1416917598, 3940066215, 387485638, 3607191060, 2022214908, 378679936, 3329038967, 844828715, 1745242011, 2737960329, 1708549368, 3704752540, 562470778, 278283912, 3434972749, 2200186094, 3892811987, 1160435877, 4250905630, 3841343115, 2402155104, 2222353060, 2657583100, 2057988113, 2778475356, 3627928159, 1708414759, 2338761127, 3014764834, 2750238892, 969700189, 4021842764, 1721126374, 4082665287, 3525096244, 74212827, 1446160187, 57960600, 2877398641, 1446256295, 219302160, 2332586777, 1762029701, 3085086764, 2694631753, 211353044, 278854492, 3828826379, 2538720355, 4257134136, 101584190, 3286392995, 1208013426, 3698628123, 999767030 ...
# g1pB_taska.txt [4036016468, 1252968955, 4217331314, 785330666, 272539016, 3367074461, 2559344458, 3094665967, 1172913709, 3265167265, 2386659178, 1617281997, 89760810, 2872494255, 3727681287, 530186651, 1469399813, 2336375521, 1418673907, 1876445483, 3558969993, 338736762, 395072793, 879569864, 282589634, 3143670163, 1565535481, 1890712408, 2978731372, 715813056, 996831685, 2686514713, 1631392281, 1083485046, 385201150, 2284811598, 2331269051, 871029911, 1238871937, 1184650805, 2867249315, 1014080892, 4062565920, 3184754858, 3224005149, 3491829747, 678986969, 3054530034, 3219564760, 3109042944, 3104846665, 3073061891, 3916115958, 743008007, 2558251843, 1493872879, 1804145438, 3157576955, 744885561, 657393441, 2303496707, 1098360094, 2401343764, 2177470056, 3609772088, 1910638174, 2447044212, 348049738, 2980835147, 1182361091, 121624013, 399949244, 4228172028, 3580447388, 1825052594, 1223371954, 606557559, 1337652831, 3809530712, 1560519832, 1007410561, 539708105, 1699267744, 118938969, 3906036819, 2831177971, 2825888359, 45824509, 2137777028, 2550034661, 1582147096, 2496304203, 1236626710, 3652974057, 1165814703, 374418042, 4191798827, 2314220291, 3767052338, 4175260318, 14122873, 2082198172, 866087637, 823115430, 3060519383, 1433463942, 2850245802, 99283396, 4169478383, 798706671, 53457121, 1910838651, 699031822, 3152075604, 2935950798, 1509650584, 1983203716, 4145296192, 313952168, 230351280, 2941854812, 1797402883, 2888085017, 2510012928, 1003838373, 505422999, 1338561911, 1639516003, 990210469, 813040602, 3698716882, 4189569692, 3913230367, 1029631639, 270012780, 776995621, 3352945655, 2207937107, 1136321505, 2811764488, 2424389049, 1898669648, 644916343, 590207017, 3018682642, 3541018015, 3887806712, 2997073379, 3968874685, 2250014073, 1394433901]
# g2pA_taska.txt [3780327974, 2442755211, 3771919802, 3938418780, 1313158532, 3968961908, 3743374241, 3709574593, 131112344, 3401583215, 2432346181, 1220343355, 2548449411, 4111896231, 28363696, 3114497749, 3064047817, 4032386761, 235331968, 3286167251, 1926147386, 4163893946, 16739445, 3882446285, 1913892359, 998364232, 3862914473, 1776582061, 4054681310, 2741666387, 4238462723, 1231879153, 3507392841, 19448297, 1691179031, 4159577240, 718129399, 789006233, 541484627, 940280500, 3566342149, 2580589553, 2707325522, 453203623, 1455045505, 2790924266, 1821168381, 3609239242, 4095370302, 753325000, 1292279315, 3052759236, 3279368718, 3158301539, 3674430416, 1355631579, 4093261595, 2803056411, 1724512996, 358193607, 3579938328, 2621477665, 4222762064, 1638006450, 3580452537, 3293598429, 2951308028, 4068098052, 2175795719, 910377347, 3118053745, 3367612400, 4255237601, 3270672186, 1636660845, 4203926834, 1506872672, 3734915851, 252264206, 4236282204, 2670362008, 1028662407, 3505804503, 2692042651, 2758294088, 3854948854, 4150292563, 241010739, 3945147670, 1778859769, 4118108842, 1147514900, 1810945134, 1527949919, 1599963605, 674989742, 2434133811, 4117472444, 3301483262, 4070137357, 858390538, 1607246163, 3913684539, 1687662769, 2083521936, 2739858861, 3462497716, 4272355245, 1833901, 2755918762, 1541384568, 642483710, 4127282450, 1929062335, 780266661, 1250504382, 536581904, 3023556542, 1927226830, 1771647689, 354601652, 3395669884, 1579914974, 3566081448, 4092826214, 3016774139, 1763923997, 3922369533, 25386256, 1685025293, 1183541384, 1044988660, 3950507185, 4269142968, 3798115392, 604363453, 2428425066, 4245605781, 208458530, 125378366, 3515971849, 985517284, 3042770005, 1505477253, 3167571234, 3352077786, 3728690896, 4167048969, 371119805, 2788619322, 3576076996, 4190048565, 3317299544, 530415335, 2012976334, 3784128988, 787182966, 3955395544, 3808974682, 2001811061, 1805939811, 2279042366, 2062533446, 1141764869, 1588456510, 4013056736, 731232176, 23824309, 350838509, 791021633, 229163530, 713300084, 981352524, 2073404466, 4158998539, 858708972, 3703990065, 3888541970, 4226655910, 345208961, 1916829772, 3559945990, 61541616, 560916485, 431609650, 1769574352, 193426980, 3213009592, 3938804218, 1605411830, 3866821853, 675804687, 1980902184, 3427232125, 3300645555, 3047027522, 1658020720, 2574909139, 1017080019, 2671035349, 2060638079, 846045835, 3464704850, 4210302334, 2538895105, 997878913, 1289849422, 2856874525, 2587145950, 3813190681, 4038782570, 1652702434, 2423401892, 1345144621, 1615766892, 182064987, 2895964873, 777983102, 1126441957, 3419733997, 3916056598, 2878267647, 1850833926, 1538262913, 4229685321, 2533375145, 4211857378, 3086803459, 3556123794, 3605364736, 3869467327, 2803565308, 2475266491, 1317851819, 1699727399, 259433454, 3766220489, 2905253232, 2428119056, 1840529588, 309209093, 558690596, 1165313335, 3721462008, 2000068114, 3735451885, 2305587192, 2984298833, 264790444, 2515484483, 1118266426, 3975994513, 1458764331, 2062704346, 1904245918, 3590382497, 2558663081, 1596839751, 3776122636, 4068127503, 1022385326, 1721715097, 1570795020, 2553737455, 2947652256, 630458067, 1302987149, 3946781118, 3121855538, 2420025364, 1595717340, 65230971, 296551898, 3388920652, 2265373417, 3516303108]
# g4pE_taska.txt [290152195, 2665455428, 2603391626, 4286207769, 767766658, 1008138334, 729682031, 1790714452, 3794426768, 1048068689, 1903206885, 3947538566, 3360081458, 4235723540, 2628674283, 78326772, 1187699979, 164441622, 3403312267, 696920871, 188960623, 2764048897, 3922872930, 2367820246, 657214829, 736752317, 4212934516, 3127937622, 3786984488, 4239458671, 4221388952, 2511787228, 2582552524, 3487418491, 580524856, 1326089930, 45507777, 3391166460, 2695029458, 1074312105, 3419388906, 1590604784, 1001197111, 1231466386, 1205371501, 2194559293, 2776740980, 300730961, 4268477356, 2661369297, 2004169414, 1884071533, 1367292258, 1004322456, 2021029128, 3133023182, 1135490555, 2424930578, 1902469093, 2762560444, 1730474691, 2867588202, 721354524, 2596392733, 593072961, 838177840, 3563433804, 1525956080, 119156398, 3072779984, 1000185699, 655015590, 1182433469, 3169969637, 3559482500, 1476396789, 1927348434, 1337869354, 2691966346, 956737824, 3869633492, 3489679302, 567564552, 652317320, 765596432, 2845136335, 169644621, 116450118, 4193289603, 2537789549, 2022533149, 357244276, 858804870, 2885753748, 4281931190, 876951048, 1233156357, 1153609684, 4048527466, 556306858, 330907757, 2826965167, 1651536136, 3260209869, 2329369179, 154802015, 2122917668, 1774785513, 1927891544, 1441052315, 977307043, 525750765, 3209317085, 18171841, 3080552373, 1521108421, 2778919844, 511661728, 662267782, 3193707796, 887564575, 3339683811, 110788254, 3408456261, 1784207193, 1797381072, 3301468536, 790051901, 2270801226, 3569482167, 2250108085, 3726426054, 2869423077, 108235196, 493386977, 2885898114, 3427770677, 2645182825, 1292822605, 580776497, 3715915742, 701230638, 2611623575, 2488793608, 4047645458, 1363180895, 1199739804, 1750343899, 3615565695, 647221307, 2414673569, 472716209, 1664927193, 3384284042, 1833902356, 847588691, 1348808948, 549722918, 1064478096, 2325836412, 2004178642, 874788425, 1681091628, 3024226408, 2032938396, 2740731564, 1121417029, 2175997510, 442552213, 1742961159, 4245784361, 2134862909, 1513699503, 1496101572, 1871940819, 1892828895, 62883570, 1784982486, 3881093819, 191062523, 2883377620, 4187285661, 25128528, 2828847685, 1182572068, 3604084093, 101044521, 872201132, 2683371770, 3426499466, 2539851769, 3145575682, 1612744071, 2774233123, 1080036865, 542185688, 871507758]
# g3pB_taska.txt [178587114, 4059178419, 3697840689, 2576912973, 3492301400, 1279850749, 1214822036, 705286110, 3903012150, 3962926115, 2831540592, 989935341, 4241800128, 2722981497, 193223469, 1318088257, 1030803821, 3513384454, 2070923043, 4161231802, 482092235, 3388294030, 703443255, 1705046280, 3544478688, 4048354062, 3571210864, 3133351033, 3147453149, 602391019, 2274978755, 3922310476, 3855286550, 754556330, 398691591, 4213733241, 510363211, 3825283500, 2184499748, 2239490429, 3501283296, 329556817, 2133827997, 1007091045, 3595810941, 2062523041, 4207257336, 3675347974, 4074694520, 3307846161, 1691773603, 3765859875, 2485731139, 2705093459, 2627704886, 3196777979, 4039997768, 327567443, 1473909891, 2632333590, 3028829978, 2774646390, 4096050462, 286912100, 371051352, 202971268, 1046867025, 2786301173, 1062741903, 3687908443, 3544108197, 3904889475, 51385521, 2330780939, 925539663, 14516526, 4229915826, 793321247, 3206750123, 482871391, 739701636, 1823836229, 1288705945, 3857881623, 281058572, 1658733102, 3093823446, 1683143227, 327131196, 3955581968, 620226957, 69030827, 2509258442, 249049408, 3796209206, 919825367, 2793527897, 994601363, 532253629, 699833163, 465370445, 3867371323, 1467827945, 73266480, 645324226, 2966771259, 876671261, 1483844796, 1365973153, 4158998539, 1995983822, 1255864920, 160123398, 339132121, 2381311787, 4217063162, 138393048, 1506475222, 3214731288, 1045942892, 2618546303, 1352566320, 4109068347, 2552738950, 252420921, 3704722749, 2126771323, 2143144704, 274035348, 748018992, 2824403208, 3962992762, 3971066672, 1770743098, 4089582437, 2254762331, 3436801090, 3479442944, 1189185892, 2317517606, 2016868849, 426695268, 240190182, 2150904671, 1681626625, 1750561889, 1874284762, 3784900305, 1273767763, 2203685301, 2677955020, 2616078106, 2153536718, 2661554485, 4271706460, 3034024780, 1927506913, 3875994540, 3445714676, 371146805, 3701492017, 1214723565, 3130149687, 4019787509, 4289547735, 1423836047, 1909919316, 3066953703, 163835821, 333233787, 3634630683, 2453252164, 1335059411, 1802691016, 1657039945, 2423844692, 249597951, 2579597214, 3858039124, 1148177041, 992301727, 2474150805, 207446052, 632449499, 3437504272, 4011892974, 494140839, 3523015960, 3118868679, 4123401237, 199061401, 1779651928, 469142406, 1872931658, 3208507631, 2573162004, 3986175961]

# %%
# Printing 5 shingles ascii values for each doc in Original_Sample folder
for k, v in Original_Sample_5shingleindex.items():
  print(k,v)
# Out:
# orig_taska.txt [1035909868, 3522252604, 3650526023, 2415088819, 106079012, 386417840, 2428879660, 1636707444, 872100460, 2070353702, 894738349, 2086421377, 1647580203, 2650612638, 3596835944, 1397217018, 686424120, 968175045, 4061552481, 1769612873, 1164183376, 1172303953, 197289567, 332416369, 3564084430, 1814713470, 4107243968, 2893812946, 3265898133, 506707586, 151640360, 3980593147, 2424194053, 3798869516, 1566471313, 3007150453, 821103029, 2593255283, 558682633, 3127021506, 348932217, 1289974384, 4249238232, 3545989964, 1099188612, 1399248073, 3647139428, 3703599356, 902908492, 2344093736, 480330746, 4043496080, 1501133475, 1351810778, 3647544276, 3743064535, 3453396159, 2844940844, 934695594, 810909792, 2347918734, 2423216601, 1558167495, 3822264706, 2811734458, 1252468044, 2541320878, 1436389364, 2096345873, 2369231483, 775395997, 932054888, 2453987871, 2081512033, 687854264, 1214439492, 184395841, 4187836544, 162363326, 4259330740, 735396003, 3959158388, 1835753496, 2159643322, 778637223, 308237136, 1091345905, 4256990993, 1759767805, 3479633242, 3362358661, 1710466, 2079628569, 1841911956, 204648415, 2864103749, 1019907181, 1302624531, 3900462815, 3983539585, 16337946, 2433495, 457892948, 1537381683, 1004150057, 2786664109, 3439293222, 1550587169, 3172289034, 2899196164, 3787597926, 1038636143, 3742002473, 3028026826, 995772961, 1280052140, 1936089769, 1378777799, 3918834569, 859004922, 1027085553, 1651406132, 2843854633, 89368477, 520627703, 2372361686, 4204947023, 3984524694, 2149528414, 147704711, 1592602593, 3758347120, 1896395363, 2075822635, 3294861906, 4153939459, 2876027697, 39868228, 3785696998, 1989055910, 325294962, 2947052942, 3363530049, 1050051865, 9408795, 1916128529, 1724735003, 27695221, 427592712, 1750879183, 3163488223, 2767191386, 1578059722, 3429803910, 2176781747, 1750652007, 1567384800, 3443551103, 13500466, 827335375, 1130702791, 646784272, 2308933436, 1204061776, 524416111, 2071375646, 1409355762, 4220296611, 3947499601, 994336980, 1413478770, 2796211866, 4190192049, 2907349466, 3277842434, 1525792105, 419785404, 2592478807, 2921047591, 225826009, 492984438, 4208825427, 1666298309, 3559501881, 69345169, 1782702186, 2495438552, 2751280597, 1257384031, 1159595757, 3333357526, 2061484896, 3395033398, 1002000852, 1365549341, 2807312361, 2154197414, 4263055171, 2264117725, 715743026, 4006251814, 497712922, 1637319343, 2532357969, 2178513272, 2558777934, 3293747878, 2848434371, 3610844352, 2565881302, 2063142498, 3813729578, 133876743, 1472696636, 3154032026, 3876972120, 2187237585, 3629128589, 181686452, 2795950856, 4094074759, 1808563720, 3250564229, 959636533, 1080520389, 1905144219, 765551172, 3811757916, 19420116, 1675097331, 1552156918, 1960673684, 1196882081, 3879680720, 1429979577, 1758399809, 3816100538, 805147146, 1437875675, 977379383, 148041192, 2482909174, 1079080651, 3510319730, 1056332005, 4153437414, 3440974417, 3930340311, 686454280, 2607765866, 1164930787, 2738204602, 2389708484, 1980558038, 1951436324, 1468243728, 2278137137, 1501854149, 4104727474, 3987608424, 1258841796, 2856392272, 1610700597, 1869204096, 689900833, 969700189, 4021842764, 1721126374, 4082665287, 3525096244, 74212827, 1446160187, 57960600, 2877398641, 1446256295, 219302160, 2332586777, 1762029701, 3085086764, 1624720636, 1253277695, 1102811774, 822206685, 3247336154, 1570601185, 1340349598, 2163164539, 1784769955, 1166957135, 692577982, 3759297686, 1168183031, 234637288, 839254698, 246217866, 419610594, 482823259, 4188250032]

# %%
#Getting the count of unique 5 shingles from Data_sample folder and Orig_Sample folder
all_unique_5shingles_index=set()
for k, v in data_Sample_5shingleindex.items():
  for i in v:
   all_unique_5shingles_index.add(i)
for k, v in Original_Sample_5shingleindex.items():
  for i in v:
   all_unique_5shingles_index.add(i)

# %%
len(all_unique_5shingles_index)
# Out:
# 3439

# %%
# Just a cross check for my understanding
# Here, I am checking the total number of unique shingles from each doc. This is equal to 4142. This is different than the number 
# of unique shingles in all the documents, which is 3439 as calculated in one of the above cells. This means some shingles are
# common even across the different documents. Hence 3439(count of unique shingles from all docs) < 4142( sum of unique shingles from each doc)
t=0
for k, v in data_Sample_5shingleindex.items():
  #print(len(v))
  t+=len(v)
print(t)
# Out:
# 4142

# %% [markdown]
# ### STEP - 2: Min-Hashing (40 points)

# %%
# ***************************************************NEW***********************************************************
# Generate Hash functions - 
    # We use (ax + b) mod N formula to permute shingle index
    # where a,b are random numbers, N total index size, and x is the index
# We need to do L permutations - In other words we need to have L permutations (lists) of new indexes
# Following function takes total index size N and L as arguments
    # And returns L new lists of size N
    
def get_hash_functions(N,L):
    hash_functions = []
    
    for itr in range(L):
        a=randrange(1,400)
        b=randrange(1,400)
        
        new_hash_function = []
        for i in range(N):
            new_hash_function.append((a * i + b) % N)
        
        hash_functions.append(new_hash_function)
    return hash_functions
        
# test
# hash_functions = get_hash_functions(3439,50)

# %%
L= [50,100,200,500,1000]

# %%
# Type your code here to generate all L hash functions
# Generate hash functions only for shingle index created for k=5
#Generating a
h_f=[]
for i in L:
  hash_functions=get_hash_functions(len(all_unique_5shingles_index),i)
  h_f.append(hash_functions)

# %%
print("Number of L's:",str(len(h_f)))
print("Number of hash functions in each of the 5 L's:")
for i in range(0,len(h_f)):
  print(len(h_f[i]))
# Out:
# Number of L's: 5
# Number of hash functions in each of the 5 L's:
# 50
# 100
# 200
# 500
# 1000

# %%
# Type your code here to get the final signature matrix S here

# %%
def generate_signaturematrix(docsshingles_index,allshingles_index,hash_functions,L):
  all=[]
  #docs=[]
  for k,v in docsshingles_index.items():
    middle=[np.inf for r in [None]*L]
    #for i in range(0,3439):
    for m in allshingles_index:
      if (m in v):
        i=list(allshingles_index).index(m)
        for j in range(0,len(hash_functions)):
          if hash_functions[j][i]<middle[j]:
            middle[j]=hash_functions[j][i]
            #print(middle) #use this print to check
    #docs.append(k)
    all.append(middle)
  return np.array(all).T

# %%
# Reporting signature matrices for each L hash fucntions where L=[50,100,200,500,1000]
all_orig_sign_matrices=[]
all_data_sign_matrices=[]
for z in range(0,len(h_f)):
  orig_sample_signmatrix=generate_signaturematrix(Original_Sample_5shingleindex,all_unique_5shingles_index,h_f[z],len(h_f[z]))
  data_sample_signmatrix=generate_signaturematrix(data_Sample_5shingleindex,all_unique_5shingles_index,h_f[z],len(h_f[z]))
  all_orig_sign_matrices.append(orig_sample_signmatrix)
  all_data_sign_matrices.append(data_sample_signmatrix)

# %%
for i in range(0,len(all_data_sign_matrices)):
  # all_data_sign_matrices is a list of signature matrices for L=[50,100,200,500,1000] respectively
  print("Data Sample folder signature matrices size for L =",str(len(all_data_sign_matrices[i])),":",str(all_data_sign_matrices[i].shape))
  # all_orig_sign_matrices is a list of signature matrices for L=[50,100,200,500,1000] respectively
  print("Original Sample folder signature matrices size for L =",str(len(all_orig_sign_matrices[i])),":",str(all_orig_sign_matrices[i].shape))
# Out:
# Data Sample folder signature matrices size for L = 50 : (50, 19)
# Original Sample folder signature matrices size for L = 50 : (50, 1)
# Data Sample folder signature matrices size for L = 100 : (100, 19)
# Original Sample folder signature matrices size for L = 100 : (100, 1)
# Data Sample folder signature matrices size for L = 200 : (200, 19)
# Original Sample folder signature matrices size for L = 200 : (200, 1)
# Data Sample folder signature matrices size for L = 500 : (500, 19)
# Original Sample folder signature matrices size for L = 500 : (500, 1)
# Data Sample folder signature matrices size for L = 1000 : (1000, 19)
# Original Sample folder signature matrices size for L = 1000 : (1000, 1)

# %%
# Printing signature matrices for all L=50 for data and original sample files. As its lenghty to print, 
# printing only for L=50, To get for other L's
# the index can be cahnegd
print(all_data_sign_matrices[0])
print(all_orig_sign_matrices[0])
# Out:
# [[ 28  10   3  14   8  24  44   5   1   5   5  29  33  19   1   0   4   9
#    13]
#  [ 38   9   0   5  49   6   7   3   3  10   1  12   2  18   4  29  36  14
#    39]
#  [  4  43  10   2   0   3  13   2   2   2   2  65  14  16   2  39   5   1
#    23]
#  [ 50  30  56  49   1   8   3   2   4   4  28   5  33   6  15   0   7  12
#    26]
#  [  9  10  42  11   4  36   1  11  11  11  11  16   7  46   2   3   0  29
#    18]
#  [ 25   8   0   2  33  29   5   2   2   2  24   4   1  22  11  15   3   6
#    57]
#  [  6   3  16   5   7  26  12   2   2  69  17  10   0   2   1  28   9  38
#    20]
#  [  3   1  33   6  14  52  26  10  17  24  17  19  25   5  36  29   0   4
#     8]
#  [ 11  10  42  18   3  21   6   1   1   9   1  22   0   2  15  69   8  20
#    53]
#  [ 33   3  26  76   7   4   5  12  17  17  15   9   2  95  11  28   0   1
#    13]
#  [ 37  13  42   5  14  48   2  15   7   6  15   0   3  11   1  36   8   4
#     9]
#  [ 35  29  12   0   4  42   2   1   1   1   1   5   6  15  19  11  10   3
#    30]
#  [ 17   0  14  38  21   5  28  18  18  18  32   3   9  11   4   7   1  12
#    13]
#  [  3  18   4  49   0   5  25  15  15   7  15  11   2  17  10  64   6  28
#    16]
#  [ 53   1   8   0   4   7  66  13  10   2  16   5  23  38   6   3   9  19
#    15]
#  [ 32   5  15   1   3   8  20   9  10   1  36   7  35  34  19   0   4   6
#    18]
#  [ 36  17  36  17  17  17  17  17  17  17  55  55  17  55  36  93  17  17
#    55]
#  [  7   1   2  29   8  33  24  22  26  13  26  15   0  18   6  16  12   3
#    21]
#  [  4  31   9  11  13  16   6   0   1   1  58  17  10  50   8  29  37   3
#     5]
#  [ 55   1   3  10   6   0  33   7   7  24   7   2 104   5  17   4  23   9
#    21]
#  [  6   3  24  34   5   2  39   9  13  13  34  16   1  58  14   0  30   4
#    17]
#  [ 19   6   2  46   5  14   0  17  18  17  41  30   4   3  17  12   1  16
#    28]
#  [  5  66  40  20   4  13   1  51  15  51 111   3  27   0  12  14  37   2
#    10]
#  [ 27   2  13  19   3  11  47  19  19  19  87  48   8  16   7   1   0  23
#    10]
#  [ 25  35   0  27   4   9  10  27  20  18  27   2  40   7   8 100   1  86
#     6]
#  [  8   0  19   1  11  10  22   2   2  34  47  24   5   7   2  25   9   4
#     3]
#  [ 20   3  90   2  11  38  51   6   6   6  16   0   7   4   5  21  19  65
#    14]
#  [  2  11   8  32  16   9   7  14  32  20  80  26  40   3   0  19   1   4
#    58]
#  [  1  21  19  35  17  18  15  32  32  35  57   6   2  12   9  49  10   4
#     0]
#  [  4   6  33   0  15   1  47   0   0   0   0   5  42   3   0   2  17  16
#    18]
#  [  8   7  30   0  11  20  15   4   4  23  13   1   6  17   3  75  34  47
#    12]
#  [ 17   8   1   0   9  51  13   6   6   6  31  11   4  14  16  12   3   5
#     2]
#  [  2  30  25   4  36  15  22   6   8  46   8   0  12  10  39   3  11   1
#    26]
#  [ 22   9  11   7  26  13   6  15   0   1  40   4  12   3   0  32  30  38
#     8]
#  [ 51   3   1   2  12  37  49   2   2   0  37  48  15  30   6  36  14   4
#     9]
#  [ 10   0  23  17  21  16   2  19   1  19 101  12  18  22   6   4   3  11
#     7]
#  [ 23   4   4   4  23   4   4   4   4   4   4   4   4   4   4  42   4   4
#     4]
#  [  8  19   0   7  30   1  10   7   7   4   7   5  14  13   7  31  17  20
#    24]
#  [  5  14  45  28  40   7   6   0   0   0  33   3  10  13   2  17   4  23
#    30]
#  [  0   6   9  42  15   2  33  16  16   8  42  28  34   7   3  20  22  11
#    56]
#  [ 18  36  67   9   7   9  14   8   8   2   9   5  10  62   1 100  28   0
#     4]
#  [ 16   5   2   3   0  12  15  18  32  32  42   6   8  20   1  22   4  45
#    28]
#  [  8  14  20  13   0   1  40  11  11  16  11  38   5  15  11  10   3   9
#     2]
#  [ 22  13   3  23   0   1   4   1   1   1  15   6   5  24  14   8  17  47
#    36]
#  [  4   1   0  18   3  19  16  23  22  17  23   9   5   6  20  37   7  12
#    14]
#  [ 14  20  15  55   8  12  26   5   9  28   9   1   4   0  18   2  21   3
#     6]
#  [ 10  40  49  28   0  24   1   5   5   5  28  14   2  25   4   7  11   6
#    23]
#  [ 10  15  34  61   6  12   1   4   8   5   8   2  14  13   8  26   3  24
#     0]
#  [ 26  25  37  20   2   3  12   1   1  16   1   7  34  10   0  28  23  17
#     4]
#  [ 11  15  22  55  50  35  24  35  35  35  55   0   2   1   5   6   3   4
#     7]]
# [[ 1]
#  [ 3]
#  [ 2]
#  [ 2]
#  [11]
#  [ 2]
#  [ 2]
#  [10]
#  [ 1]
#  [17]
#  [ 7]
#  [ 1]
#  [18]
#  [15]
#  [10]
#  [10]
#  [17]
#  [22]
#  [ 1]
#  [ 7]
#  [13]
#  [17]
#  [15]
#  [19]
#  [20]
#  [ 2]
#  [ 6]
#  [20]
#  [32]
#  [ 0]
#  [ 4]
#  [ 6]
#  [ 6]
#  [ 0]
#  [ 2]
#  [19]
#  [ 4]
#  [ 7]
#  [ 0]
#  [16]
#  [ 8]
#  [32]
#  [11]
#  [ 1]
#  [22]
#  [ 5]
#  [ 5]
#  [ 4]
#  [ 1]
#  [35]]

# %% [markdown]
# ####Calculcating Jaccard Similarity

# %%
# Function to get the jaccard similarity. I used this code avaialble on the internet.
def jaccard(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(list1) + len(list2)) - intersection
    return round(float(intersection) / union,4)

# %%
def generate_jaccard_similarity(orig_signature_matrix,data_signature_matrix):
  all_sim=[]
  for i in range(0,5):
    sim=[]
    blue=orig_signature_matrix[i][:,0].tolist()
    for j in range(0,p):
      green=data_signature_matrix[i][:,j].tolist()
      sim.append(jaccard(blue,green))
    all_sim.append(sim)
  jsim_all=[]
  for m in range(0,len(all_sim)):
    j_sim={}
    for i in range(0,p):
      j_sim[doc_names[i]]=all_sim[m][i]
    jsim_all.append(j_sim)
  return jsim_all

# %%
#Here, jaccard similarity for all 19 docs with respect to original is calculated.
# This is performed across asll 5 L's
# The resulting all_sim is a list of 5 elements representing L=[50,100,200,500,1000] resp
# Each element in jsim_all is a dictionary with keys as doc names and values as its jaccard similarities with original
all_sim=[]
for i in range(0,len(L)):
  sim=[]
  blue=all_orig_sign_matrices[i][:,0].tolist()
  for j in range(0,p):
    green=all_data_sign_matrices[i][:,j].tolist()
    sim.append(jaccard(blue,green))
  all_sim.append(sim)

# %%
doc_names=[]
for k in data_Sample_5shingleindex.keys():
  doc_names.append(k)

# %%
jsim_all=[]
for m in range(0,len(all_sim)):
  j_sim={}
  for i in range(0,p):
    j_sim[doc_names[i]]=all_sim[m][i]
  jsim_all.append(j_sim)

# %%
#Each element in jsim_all has jaccard similartoes for each of L=[50,100,200,500,1000]. Here, I printed for L=1000
# Fact Check
jsim_all[4]
# Out:
# {'g0pA_taska.txt': 0.0288,
#  'g0pB_taska.txt': 0.0277,
#  'g0pC_taska.txt': 0.0293,
#  'g0pD_taska.txt': 0.0299,
#  'g0pE_taska.txt': 0.0293,
#  'g1pA_taska.txt': 0.0293,
#  'g1pB_taska.txt': 0.0299,
#  'g1pD_taska.txt': 0.0299,
#  'g2pA_taska.txt': 0.0283,
#  'g2pB_taska.txt': 0.0293,
#  'g2pC_taska.txt': 0.0293,
#  'g2pE_taska.txt': 0.0262,
#  'g3pA_taska.txt': 0.0299,
#  'g3pB_taska.txt': 0.0299,
#  'g3pC_taska.txt': 0.0293,
#  'g4pB_taska.txt': 0.0293,
#  'g4pC_taska.txt': 0.0283,
#  'g4pD_taska.txt': 0.0299,
#  'g4pE_taska.txt': 0.0293}

# %% [markdown]
# **Entire code for creating 5 shingles index, generating signature matrix for each of the L=[50,100,200,500,1000] and calculating jaccard similarities-fact check**

# %%
# Type your code here to do the fact check 
#      with any one query document in the 'Original_Sample' directory

original = 'Original_Sample/orig_taskc.txt'

# STEP-1: Generate 5-shingles 
    # (if any shingles are not present in your shingle index, simply ignore them)
data_Sample_5shingleindex=generate_shingles('/content/Data_Sample',5)
Original_Sample_5shingleindex=generate_shingles('/content/Original_Sample',5)
    
all_unique_5shingles_index=set()
for k, v in data_Sample_5shingleindex.items():
  for i in v:
   all_unique_5shingles_index.add(i)
for k, v in Original_Sample_5shingleindex.items():
  for i in v:
   all_unique_5shingles_index.add(i)    
    
# STEP-2: Generate signature vector from L hash functions
L=[50,100,200,500,1000]

h_f=[]
for i in L:
  hash_functions=get_hash_functions(len(all_unique_5shingles_index),i)
  h_f.append(hash_functions)

all_orig_sign_matrices=[]
all_data_sign_matrices=[]
for z in range(0,len(h_f)):
  orig_sample_signmatrix=generate_signaturematrix(Original_Sample_5shingleindex,all_unique_5shingles_index,h_f[z],len(h_f[z]))
  data_sample_signmatrix=generate_signaturematrix(data_Sample_5shingleindex,all_unique_5shingles_index,h_f[z],len(h_f[z]))
  all_orig_sign_matrices.append(orig_sample_signmatrix)
  all_data_sign_matrices.append(data_sample_signmatrix)

doc_names=[]
for k in data_Sample_5shingleindex.keys():
  doc_names.append(k)

# STEP-3: Calculate Jaccard similarity of signature vector of orginal doc.
    # and all other documents 
jaccard_similarities=generate_jaccard_similarity(all_orig_sign_matrices,all_data_sign_matrices)
print("************************  Jaccard Similarities for L=[50,100,200,500,1000] without any threshold*******************************************")
print(jaccard_similarities)
t = 0.20
d=[]
for e in range(0,len(jaccard_similarities)):
  d1=[]
  for k,v in jaccard_similarities[e].items():
    if v<t:
      d1.append(k)
  d.append(d1)
s=0
while s<len(d):
  #print(s)
  for i in d[s]:
    jaccard_similarities[s].pop(i)
  s+=1
print("************************* Jaccard Similarities for L=[50,100,200,500,1000] greater than t=0.2 **************************")
print(jaccard_similarities)
# Out:
# ************************  Jaccard Similarities for L=[50,100,200,500,1000] without any threshold*******************************************
# [{'g3pA_taska.txt': 0.1765, 'g0pB_taska.txt': 0.1905, 'g4pB_taska.txt': 0.1905, 'g0pD_taska.txt': 0.1765, 'g1pA_taska.txt': 0.1494, 'g1pD_taska.txt': 0.1905, 'g0pC_taska.txt': 0.1905, 'g4pC_taska.txt': 0.2195, 'g0pE_taska.txt': 0.2346, 'g2pC_taska.txt': 0.1905, 'g3pC_taska.txt': 0.1765, 'g2pB_taska.txt': 0.1765, 'g0pA_taska.txt': 0.2048, 'g4pD_taska.txt': 0.1628, 'g2pE_taska.txt': 0.1628, 'g1pB_taska.txt': 0.2195, 'g2pA_taska.txt': 0.2048, 'g4pE_taska.txt': 0.2048, 'g3pB_taska.txt': 0.1905}, {'g3pA_taska.txt': 0.1429, 'g0pB_taska.txt': 0.1429, 'g4pB_taska.txt': 0.1494, 'g0pD_taska.txt': 0.1494, 'g1pA_taska.txt': 0.1494, 'g1pD_taska.txt': 0.1429, 'g0pC_taska.txt': 0.1299, 'g4pC_taska.txt': 0.1696, 'g0pE_taska.txt': 0.1561, 'g2pC_taska.txt': 0.1299, 'g3pC_taska.txt': 0.1429, 'g2pB_taska.txt': 0.1364, 'g0pA_taska.txt': 0.1364, 'g4pD_taska.txt': 0.1494, 'g2pE_taska.txt': 0.1494, 'g1pB_taska.txt': 0.1628, 'g2pA_taska.txt': 0.1364, 'g4pE_taska.txt': 0.1364, 'g3pB_taska.txt': 0.1364}, {'g3pA_taska.txt': 0.0959, 'g0pB_taska.txt': 0.087, 'g4pB_taska.txt': 0.0929, 'g0pD_taska.txt': 0.0959, 'g1pA_taska.txt': 0.0899, 'g1pD_taska.txt': 0.0989, 'g0pC_taska.txt': 0.087, 'g4pC_taska.txt': 0.0899, 'g0pE_taska.txt': 0.1019, 'g2pC_taska.txt': 0.0989, 'g3pC_taska.txt': 0.0959, 'g2pB_taska.txt': 0.0899, 'g0pA_taska.txt': 0.084, 'g4pD_taska.txt': 0.087, 'g2pE_taska.txt': 0.0782, 'g1pB_taska.txt': 0.0989, 'g2pA_taska.txt': 0.087, 'g4pE_taska.txt': 0.0899, 'g3pB_taska.txt': 0.0959}, {'g3pA_taska.txt': 0.0471, 'g0pB_taska.txt': 0.0438, 'g4pB_taska.txt': 0.046, 'g0pD_taska.txt': 0.0493, 'g1pA_taska.txt': 0.0471, 'g1pD_taska.txt': 0.046, 'g0pC_taska.txt': 0.0493, 'g4pC_taska.txt': 0.0504, 'g0pE_taska.txt': 0.0482, 'g2pC_taska.txt': 0.0482, 'g3pC_taska.txt': 0.0504, 'g2pB_taska.txt': 0.0493, 'g0pA_taska.txt': 0.0493, 'g4pD_taska.txt': 0.0493, 'g2pE_taska.txt': 0.0417, 'g1pB_taska.txt': 0.0493, 'g2pA_taska.txt': 0.046, 'g4pE_taska.txt': 0.0449, 'g3pB_taska.txt': 0.046}, {'g3pA_taska.txt': 0.0288, 'g0pB_taska.txt': 0.0267, 'g4pB_taska.txt': 0.0283, 'g0pD_taska.txt': 0.0288, 'g1pA_taska.txt': 0.0283, 'g1pD_taska.txt': 0.0288, 'g0pC_taska.txt': 0.0283, 'g4pC_taska.txt': 0.0288, 'g0pE_taska.txt': 0.0283, 'g2pC_taska.txt': 0.0277, 'g3pC_taska.txt': 0.0288, 'g2pB_taska.txt': 0.0272, 'g0pA_taska.txt': 0.0277, 'g4pD_taska.txt': 0.0283, 'g2pE_taska.txt': 0.0246, 'g1pB_taska.txt': 0.0288, 'g2pA_taska.txt': 0.0267, 'g4pE_taska.txt': 0.0283, 'g3pB_taska.txt': 0.0288}]
# ************************* Jaccard Similarities for L=[50,100,200,500,1000] greater than t=0.2 **************************
# [{'g4pC_taska.txt': 0.2195, 'g0pE_taska.txt': 0.2346, 'g0pA_taska.txt': 0.2048, 'g1pB_taska.txt': 0.2195, 'g2pA_taska.txt': 0.2048, 'g4pE_taska.txt': 0.2048}, {}, {}, {}, {}]

# %% [markdown]
# ***************************************************NEW***********************************************************
# For each L = {50,100,200,500,1000}, report all documents (file_names) below that have Jaccard similarity > t=0.85
# Sort the documents in decreasing order of the Jaccard similarity

# %%
#This is reported above. I do not get any docs with t>0.2 except for L=50

# %% [markdown]
# ### STEP - 3: LSH (30 points)

# %%
#Generating signature matrix for L=1000
data_Sample_5shingleindex=generate_shingles('/content/Data_Sample',5)
Original_Sample_5shingleindex=generate_shingles('/content/Original_Sample',5)

all_unique_5shingles_index=set()
for k, v in data_Sample_5shingleindex.items():
  for i in v:
   all_unique_5shingles_index.add(i)
for k, v in Original_Sample_5shingleindex.items():
  for i in v:
   all_unique_5shingles_index.add(i)  

L=1000
hash_functions=get_hash_functions(len(all_unique_5shingles_index),L)
orig_sample_1000signmatrix=generate_signaturematrix(Original_Sample_5shingleindex,all_unique_5shingles_index,hash_functions,L)
data_sample_1000signmatrix=generate_signaturematrix(data_Sample_5shingleindex,all_unique_5shingles_index,hash_functions,L)

# %%
print("Size of Data Sample Signature matrix:",str(data_sample_1000signmatrix.shape))
print(data_sample_1000signmatrix)
print("Size of Original Sample Signature Matrix:",str(orig_sample_1000signmatrix.shape))
#print(orig_sample_1000signmatrix)
# Out:
# Size of Data Sample Signature matrix: (1000, 19)
# [[56 18 18 ... 18 18 56]
#  [11  0 18 ... 25 14  3]
#  [57 12  5 ...  0 19  8]
#  ...
#  [ 5  5  5 ...  5 43  5]
#  [27 19 11 ... 14  7 31]
#  [30 11  4 ...  0  8  1]]
# Size of Original Sample Signature Matrix: (1000, 1)

# %%
# Type your code here to hash signature matrix into B buckets
# Use the technique to split the signature matrix into b bands of r rows
# Convert only the signature matrix generated with L=1000

b = 50
r = 20
B = 199

# %%
def generate_bands_hash(signaturematrix,bands,rowsinband,buckets):
  allbands=[]
  for z in range(0,bands): # 50 is number of bands
    l=0
    h=rowsinband
    x=signaturematrix[l:h]
    band=[]
    for i in range(0,len(signaturematrix[0])):
      zoo=random.sample(range(100),rowsinband)
      igloo=0 
      for j in range(0,rowsinband):
        igloo+=x[:,i][j]*zoo[j] 
      band.append(igloo % buckets)
    allbands.append(band)
    l=h
    h=h+rowsinband
  return np.array(allbands)

# %% [markdown]
# Generating Candidate Documents, False Positives, False Ngeatives
# Now, I have 50 bands for 19 docs and 50 bands for 1 original doc.
# Candidate docs are identified using the following criteria.
# For doc1, band1(doc1) is compared with band1(orig).
# In the 50 bands, if atleast one band value is common, which means they fall into same bucket. In this case, doc1 is a candidate document. This process is repeated over 19 docs comparing with original for all corresponding 50 bands.

# %%
def generate_cand_fp_fn(orig_hash_sig_matrix,data_hash_sig_matrix,t):
  hava={}
  candidate_documents=[]
  o=orig_hash_sig_matrix[:,0].tolist()
  for i in range(0,p):
    d=data_hash_sig_matrix[:,i].tolist()
    count=0
    for j in range(0,b):
      if o[j]==d[j]:
        count+=1
    if count>=1:
      hava[doc_names[i]]=count
    #print(doc_names[i])
      candidate_documents.append(doc_names[i])
  print("************************* Candidate Documents ********************************")
  print(candidate_documents)
  print("                         ")
  print("************* Candidate documents and how many buckets in common with the original document ************")
  print(hava)
  print("                         ")
  plus={}
  j=[]
  o=orig_hash_sig_matrix[:,0].tolist()
  for i in range(0,p):
    d=data_hash_sig_matrix[:,i].tolist()
    j.append(jaccard(o,d))
    plus[doc_names[i]]=jaccard(o,d)
# Reporting jaccard similarites for candidate docs
  print("************* Jaccard Similarities of Candidate Documents *****************")
  for k, v in plus.items():
    if k in candidate_documents:
      print(k,v)
  print("                         ")
  false_positives={}
  for c in candidate_documents:
    if plus[c]<=t:
      false_positives[c]=plus[c]
  print("                                              ")
  print("****************** All documents with Jaccard Similarity >t=0.1************************")
  alldocgreat_jt=[]
  for k, v in plus.items():
    if v>t:
     alldocgreat_jt.append(k)
  print(alldocgreat_jt)
  print("                                     ")
  print("Count of False Positives:", len(false_positives))
  print("********* False positive documents and their corresponding Jaccard Similarity *************")
  print(false_positives)
  print("                         ")
  false_negatives={}
  for k,v in plus.items():
    if v>t and k not in candidate_documents:
      false_negatives[k]=v
  print("Count of False Negatives:", len(false_negatives))
  print("************ False negative documents and their corresponding Jaccard Similarity *************")
  print(false_negatives)

# %%
# Type your code here to do generate candidate documents
# Follow all steps from STEP - 2 fact check (except the Jaccard similarity part)

# STEP - 1: Split your original document signature vector into b bands of r rows

# STEP - 2: Hash using the same hash functions created for 
    # signature matrix hashing (in the previous cell)
orig_bands_hash=generate_bands_hash(orig_sample_1000signmatrix,b,r,B)
orig_bands_hash.shape
# Out:
# (50, 1)

# %%
# Type your code here to do the fact check
# Calculate Jaccard similarity of the roiginal document with only 
    # candidate documents

# %% [markdown]
# Report all documents (file_names) below that have Jaccard similarity > t=0.85
# Sort the documents in decreasing order of the Jaccard similarity

# %% [markdown]
# Report the list of false positives and false negatives below

# %% [markdown]
# I reported **candidaite docs**, **all docs with jaccard similarity >t=0.1** and **false positives**, **false negatives** in the below cell.
# As I have only 19 docs, none of the docs have above 0.2. The max I am gettinf is 0.19. So,I am checking with t=0.1

# %%
b = 50
r = 20
B = 199
print("                                                                                                             ")
print("******************** Results for b =", str(b),"r =", str(r), "B =", str(B),"**********************************")
print("                                                                                                           ")
orig_bands_hash=generate_bands_hash(orig_sample_1000signmatrix,b,r,B)
data_bands_hash=generate_bands_hash(data_sample_1000signmatrix,b,r,B)
t=0.1
generate_cand_fp_fn(orig_bands_hash,data_bands_hash,t)
# Out:
#
# ******************** Results for b = 50 r = 20 B = 199 **********************************
#
# ************************* Candidate Documents ********************************
# ['g0pC_taska.txt', 'g2pB_taska.txt', 'g1pB_taska.txt']
#
# ************* Candidate documents and how many buckets in common with the original document ************
# {'g0pC_taska.txt': 1, 'g2pB_taska.txt': 1, 'g1pB_taska.txt': 1}
#
# ************* Jaccard Similarities of Candidate Documents *****************
# g0pC_taska.txt 0.0638
# g2pB_taska.txt 0.087
# g1pB_taska.txt 0.087
#
#
# ****************** All documents with Jaccard Similarity >t=0.1************************
# ['g4pB_taska.txt', 'g1pD_taska.txt', 'g4pC_taska.txt', 'g3pC_taska.txt']
#
# Count of False Positives: 3
# ********* False positive documents and their corresponding Jaccard Similarity *************
# {'g0pC_taska.txt': 0.0638, 'g2pB_taska.txt': 0.087, 'g1pB_taska.txt': 0.087}
#
# Count of False Negatives: 4
# ************ False negative documents and their corresponding Jaccard Similarity *************
# {'g4pB_taska.txt': 0.1364, 'g1pD_taska.txt': 0.1111, 'g4pC_taska.txt': 0.1111, 'g3pC_taska.txt': 0.1494}

# %% [markdown]
# ### Optimizing with different number of bands, rows and buckets

# %%
# Experiment with different values of b,r,B, and t
    # to reduce the number of false positives and false negatives
    # Report all results in a table in a separate word document

# %%
b = 40
r = 25
B = 199
print("******************** Results for b =", str(b),"r =", str(r), "B =", str(B),"**********************************")
print("                                                                                                           ")
orig_bands_hash=generate_bands_hash(orig_sample_1000signmatrix,b,r,B)
data_bands_hash=generate_bands_hash(data_sample_1000signmatrix,b,r,B)
t=0.1
generate_cand_fp_fn(orig_bands_hash,data_bands_hash,t)
# Out:
# ******************** Results for b = 40 r = 25 B = 199 **********************************
#
# ************************* Candidate Documents ********************************
# ['g4pB_taska.txt', 'g1pB_taska.txt', 'g4pE_taska.txt']
#
# ************* Candidate documents and how many buckets in common with the original document ************
# {'g4pB_taska.txt': 1, 'g1pB_taska.txt': 1, 'g4pE_taska.txt': 1}
#
# ************* Jaccard Similarities of Candidate Documents *****************
# g4pB_taska.txt 0.0667
# g1pB_taska.txt 0.1111
# g4pE_taska.txt 0.1111
#
#
# ****************** All documents with Jaccard Similarity >t=0.1************************
# ['g0pD_taska.txt', 'g2pB_taska.txt', 'g2pE_taska.txt', 'g1pB_taska.txt', 'g4pE_taska.txt', 'g3pB_taska.txt']
#
# Count of False Positives: 1
# ********* False positive documents and their corresponding Jaccard Similarity *************
# {'g4pB_taska.txt': 0.0667}
#
# Count of False Negatives: 4
# ************ False negative documents and their corresponding Jaccard Similarity *************
# {'g0pD_taska.txt': 0.1111, 'g2pB_taska.txt': 0.1268, 'g2pE_taska.txt': 0.1268, 'g3pB_taska.txt': 0.1111}

# %%
b = 10
r = 100
B = 99
print("******************** Results for b =", str(b),"r =", str(r), "B =", str(B),"**********************************")
print("                                                                                                           ")
orig_bands_hash=generate_bands_hash(orig_sample_1000signmatrix,b,r,B)
data_bands_hash=generate_bands_hash(data_sample_1000signmatrix,b,r,B)
t=0.1
generate_cand_fp_fn(orig_bands_hash,data_bands_hash,t)
# Out:
# ******************** Results for b = 10 r = 100 B = 99 **********************************
#
# ************************* Candidate Documents ********************************
# ['g0pC_taska.txt']
#
# ************* Candidate documents and how many buckets in common with the original document ************
# {'g0pC_taska.txt': 1}
#
# ************* Jaccard Similarities of Candidate Documents *****************
# g0pC_taska.txt 0.0526
#
#
# ****************** All documents with Jaccard Similarity >t=0.1************************
# ['g0pD_taska.txt', 'g0pE_taska.txt', 'g0pA_taska.txt']
#
# Count of False Positives: 1
# ********* False positive documents and their corresponding Jaccard Similarity *************
# {'g0pC_taska.txt': 0.0526}
#
# Count of False Negatives: 3
# ************ False negative documents and their corresponding Jaccard Similarity *************
# {'g0pD_taska.txt': 0.1111, 'g0pE_taska.txt': 0.1765, 'g0pA_taska.txt': 0.1111}

# %%
b = 125
r = 8
B = 300
print("******************** Results for b =", str(b),"r =", str(r), "B =", str(B),"**********************************")
print("                                                                                                           ")
orig_bands_hash=generate_bands_hash(orig_sample_1000signmatrix,b,r,B)
data_bands_hash=generate_bands_hash(data_sample_1000signmatrix,b,r,B)
t=0.1
generate_cand_fp_fn(orig_bands_hash,data_bands_hash,t)
# Out:
# ******************** Results for b = 125 r = 8 B = 300 **********************************
#
# ************************* Candidate Documents ********************************
# ['g4pB_taska.txt', 'g0pD_taska.txt', 'g1pA_taska.txt', 'g3pC_taska.txt', 'g0pA_taska.txt', 'g4pD_taska.txt', 'g3pB_taska.txt']
#
# ************* Candidate documents and how many buckets in common with the original document ************
# {'g4pB_taska.txt': 1, 'g0pD_taska.txt': 1, 'g1pA_taska.txt': 1, 'g3pC_taska.txt': 1, 'g0pA_taska.txt': 1, 'g4pD_taska.txt': 2, 'g3pB_taska.txt': 1}
#
# ************* Jaccard Similarities of Candidate Documents *****************
# g4pB_taska.txt 0.1364
# g0pD_taska.txt 0.1364
# g1pA_taska.txt 0.1628
# g3pC_taska.txt 0.1468
# g0pA_taska.txt 0.1312
# g4pD_taska.txt 0.1792
# g3pB_taska.txt 0.1211
#
#
# ****************** All documents with Jaccard Similarity >t=0.1************************
# ['g3pA_taska.txt', 'g0pB_taska.txt', 'g4pB_taska.txt', 'g0pD_taska.txt', 'g1pA_taska.txt', 'g1pD_taska.txt', 'g0pC_taska.txt', 'g4pC_taska.txt', 'g0pE_taska.txt', 'g2pC_taska.txt', 'g3pC_taska.txt', 'g2pB_taska.txt', 'g0pA_taska.txt', 'g4pD_taska.txt', 'g2pE_taska.txt', 'g1pB_taska.txt', 'g2pA_taska.txt', 'g4pE_taska.txt', 'g3pB_taska.txt']
#
# Count of False Positives: 0
# ********* False positive documents and their corresponding Jaccard Similarity *************
# {}
#
# Count of False Negatives: 12
# ************ False negative documents and their corresponding Jaccard Similarity *************
# {'g3pA_taska.txt': 0.1682, 'g0pB_taska.txt': 0.1848, 'g1pD_taska.txt': 0.1682, 'g0pC_taska.txt': 0.1574, 'g4pC_taska.txt': 0.1521, 'g0pE_taska.txt': 0.1161, 'g2pC_taska.txt': 0.1416, 'g2pB_taska.txt': 0.1416, 'g2pE_taska.txt': 0.1312, 'g1pB_taska.txt': 0.1416, 'g2pA_taska.txt': 0.1364, 'g4pE_taska.txt': 0.1468}

# %%
b = 25
r = 40
B = 300
print("******************** Results for b =", str(b),"r =", str(r), "B =", str(B),"**********************************")
print("                                                                                                           ")
orig_bands_hash=generate_bands_hash(orig_sample_1000signmatrix,b,r,B)
data_bands_hash=generate_bands_hash(data_sample_1000signmatrix,b,r,B)
t=0.1
generate_cand_fp_fn(orig_bands_hash,data_bands_hash,t)
# Out:
# ******************** Results for b = 25 r = 40 B = 300 **********************************
#
# ************************* Candidate Documents ********************************
# ['g4pD_taska.txt']
#
# ************* Candidate documents and how many buckets in common with the original document ************
# {'g4pD_taska.txt': 1}
#
# ************* Jaccard Similarities of Candidate Documents *****************
# g4pD_taska.txt 0.0204
#
#
# ****************** All documents with Jaccard Similarity >t=0.1************************
# []
#
# Count of False Positives: 1
# ********* False positive documents and their corresponding Jaccard Similarity *************
# {'g4pD_taska.txt': 0.0204}
#
# Count of False Negatives: 0
# ************ False negative documents and their corresponding Jaccard Similarity *************
# {}

# %%
b = 100
r = 10
B = 1000
print("******************** Results for b =", str(b),"r =", str(r), "B =", str(B),"**********************************")
print("                                                                                                           ")
orig_bands_hash=generate_bands_hash(orig_sample_1000signmatrix,b,r,B)
data_bands_hash=generate_bands_hash(data_sample_1000signmatrix,b,r,B)
t=0.1
generate_cand_fp_fn(orig_bands_hash,data_bands_hash,t)
# Out:
# ******************** Results for b = 100 r = 10 B = 1000 **********************************
#
# ************************* Candidate Documents ********************************
# ['g2pC_taska.txt', 'g4pD_taska.txt', 'g1pB_taska.txt', 'g4pE_taska.txt']
#
# ************* Candidate documents and how many buckets in common with the original document ************
# {'g2pC_taska.txt': 1, 'g4pD_taska.txt': 1, 'g1pB_taska.txt': 1, 'g4pE_taska.txt': 1}
#
# ************* Jaccard Similarities of Candidate Documents *****************
# g2pC_taska.txt 0.0471
# g4pD_taska.txt 0.0526
# g1pB_taska.txt 0.0471
# g4pE_taska.txt 0.0417
#
#
# ****************** All documents with Jaccard Similarity >t=0.1************************
# []
#
# Count of False Positives: 4
# ********* False positive documents and their corresponding Jaccard Similarity *************
# {'g2pC_taska.txt': 0.0471, 'g4pD_taska.txt': 0.0526, 'g1pB_taska.txt': 0.0471, 'g4pE_taska.txt': 0.0417}
#
# Count of False Negatives: 0
# ************ False negative documents and their corresponding Jaccard Similarity *************
# {}

# %% [markdown]
# #**************************************************************************************
